# %%
Подключаем библиотеки

# %%
import pandas as pd

# %%
pd.DataFrame([[1,5,6,3], [1,5,6,3]], index=['station_1', 'station_2'], columns=['wind', 'solar', 'pressure', 'speed'])
# Out:
#            wind  solar  pressure  speed
# station_1     1      5         6      3
# station_2     1      5         6      3

# %%
df = pd.read_csv('data_And.csv', encoding='1251')
df
# Out:
#           DR_Dat    DR_Tim  DR_NChk   DR_NDoc  DR_Apt  DR_Kkm  \
# 0     2022-08-11  10:15:35     2173   2004598       2   22577
# 1     2022-08-11  10:27:46     2174   2004598       2   22577
# 2     2022-08-11  10:27:46     2174   2004598       2   22577
# 3     2022-08-11  10:27:46     2174   2004598       2   22577
# 4     2022-08-11  10:33:56     2175   2004598       2   22577
# ...          ...       ...      ...       ...     ...     ...
# 4457  2022-08-12  21:40:17     5690  18002542      18    9907
# 4458  2022-08-12  21:40:59     5691  18002542      18    9907
# 4459  2022-08-12  21:43:48     5692  18002542      18    9907
# 4460  2022-08-12  21:44:46     5693  18002542      18    9907
# 4461  2022-08-12  21:46:08     5694  18002542      18    9907
#
#                    DR_TDoc  DR_TPay  DR_CDrugs  \
# 0     Розничная реализация       18      45399
# 1     Розничная реализация       15     261519
# 2     Розничная реализация       15     460864
# ...

# %%
df.head(10)
# Out:
#        DR_Dat    DR_Tim  DR_NChk  DR_NDoc  DR_Apt  DR_Kkm  \
# 0  2022-08-11  10:15:35     2173  2004598       2   22577
# 1  2022-08-11  10:27:46     2174  2004598       2   22577
# 2  2022-08-11  10:27:46     2174  2004598       2   22577
# 3  2022-08-11  10:27:46     2174  2004598       2   22577
# 4  2022-08-11  10:33:56     2175  2004598       2   22577
# 5  2022-08-11  10:40:38     2176  2004598       2   22577
# 6  2022-08-11  10:40:38     2176  2004598       2   22577
# 7  2022-08-11  10:52:52     2177  2004598       2   22577
# 8  2022-08-11  10:52:52     2177  2004598       2   22577
# 9  2022-08-11  10:52:52     2177  2004598       2   22577
#
#                 DR_TDoc  DR_TPay  DR_CDrugs  \
# 0  Розничная реализация       18      45399
# 1  Розничная реализация       15     261519
# 2  Розничная реализация       15     460864
# 3  Розничная реализация       15     172823
# 4  Розничная реализация       18      79056
# 5  Розничная реализация       18     187304
# ...

# %%
df.tail(3)
# Out:
#           DR_Dat    DR_Tim  DR_NChk   DR_NDoc  DR_Apt  DR_Kkm  \
# 4459  2022-08-12  21:43:48     5692  18002542      18    9907
# 4460  2022-08-12  21:44:46     5693  18002542      18    9907
# 4461  2022-08-12  21:46:08     5694  18002542      18    9907
#
#                    DR_TDoc  DR_TPay  DR_CDrugs  \
# 4459  Розничная реализация       18     260990
# 4460  Розничная реализация       18      41512
# 4461  Розничная реализация       15      25673
#
#                                               DR_NDrugs  ...  \
# 4459  СИЛДЕНАФИЛ-СЗ 50МГ. №10 ТАБ. П/П/О /СЕВЕРНАЯ З...  ...
# 4460                         ТОБРАЗОН 5МЛ. ГЛ.КАПЛИ ФЛ.  ...
# 4461  БЕЛЬВЕДЕР ЛАК П/ОБГРЫЗАНИЯ НОГТЕЙ 8МЛ. [BELWEDER]  ...
#
#                                     DR_Prod DR_Kol  DR_CZak  DR_CRoz  \
# 4459                        Северная Звезда    1.0   297.74    396.0
# 4460  Кадила Фармасьютикалз Лтд  ( CADILA )    1.0   322.06    419.0
# ...

# %%
pd.set_option('display.max_columns', 40)

# %%
df.tail(3)
# Out:
#           DR_Dat    DR_Tim  DR_NChk   DR_NDoc  DR_Apt  DR_Kkm  \
# 4459  2022-08-12  21:43:48     5692  18002542      18    9907
# 4460  2022-08-12  21:44:46     5693  18002542      18    9907
# 4461  2022-08-12  21:46:08     5694  18002542      18    9907
#
#                    DR_TDoc  DR_TPay  DR_CDrugs  \
# 4459  Розничная реализация       18     260990
# 4460  Розничная реализация       18      41512
# 4461  Розничная реализация       15      25673
#
#                                               DR_NDrugs        DR_Suppl  \
# 4459  СИЛДЕНАФИЛ-СЗ 50МГ. №10 ТАБ. П/П/О /СЕВЕРНАЯ З...          Авеста
# 4460                         ТОБРАЗОН 5МЛ. ГЛ.КАПЛИ ФЛ.  Катрен г.Химки
# 4461  БЕЛЬВЕДЕР ЛАК П/ОБГРЫЗАНИЯ НОГТЕЙ 8МЛ. [BELWEDER]  Катрен г.Химки
#
#                                     DR_Prod  DR_Kol  DR_CZak  DR_CRoz  \
# 4459                        Северная Звезда     1.0   297.74    396.0
# 4460  Кадила Фармасьютикалз Лтд  ( CADILA )     1.0   322.06    419.0
# ...

# %%
pd.describe_option()
# Out:
# compute.use_bottleneck : bool
#     Use the bottleneck library to accelerate if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
# compute.use_numba : bool
#     Use the numba engine option for select operations if it is installed,
#     the default is False
#     Valid values: False,True
#     [default: False] [currently: False]
# compute.use_numexpr : bool
#     Use the numexpr library to accelerate computation if it is installed,
#     the default is True
#     Valid values: False,True
#     [default: True] [currently: True]
# display.chop_threshold : float or None
#     if set to a float value, all float values smaller than the given threshold
#     will be displayed as exactly 0 by repr and friends.
#     [default: None] [currently: None]
# display.colheader_justify : 'left'/'right'
#     Controls the justification of column headers. used by DataFrameFormatter.
#     [default: right] [currently: right]
# ...

# %%
pd.get_option('display.max_columns')
# Out:
# 20

# %%
df.dtypes
# Out:
# DR_Dat         object
# DR_Tim         object
# DR_NChk         int64
# DR_NDoc         int64
# DR_Apt          int64
# DR_Kkm          int64
# DR_TDoc        object
# DR_TPay         int64
# DR_CDrugs       int64
# DR_NDrugs      object
# DR_Suppl       object
# DR_Prod        object
# DR_Kol        float64
# DR_CZak       float64
# DR_CRoz       float64
# DR_SDisc      float64
# DR_CDisc      float64
# DR_BCDisc     float64
# DR_TabEmpl      int64
# DR_VZak         int64
# DR_Pos        float64
# dtype: object

# %%
pd.set_option('display.float_format', '{:.2f}'.format) #кастомизируем вывод десятичных чисел

# %%
df.tail(3)
# Out:
#           DR_Dat    DR_Tim  DR_NChk   DR_NDoc  DR_Apt  DR_Kkm  \
# 4459  2022-08-12  21:43:48     5692  18002542      18    9907
# 4460  2022-08-12  21:44:46     5693  18002542      18    9907
# 4461  2022-08-12  21:46:08     5694  18002542      18    9907
#
#                    DR_TDoc  DR_TPay  DR_CDrugs  \
# 4459  Розничная реализация       18     260990
# 4460  Розничная реализация       18      41512
# 4461  Розничная реализация       15      25673
#
#                                               DR_NDrugs        DR_Suppl  \
# 4459  СИЛДЕНАФИЛ-СЗ 50МГ. №10 ТАБ. П/П/О /СЕВЕРНАЯ З...          Авеста
# 4460                         ТОБРАЗОН 5МЛ. ГЛ.КАПЛИ ФЛ.  Катрен г.Химки
# 4461  БЕЛЬВЕДЕР ЛАК П/ОБГРЫЗАНИЯ НОГТЕЙ 8МЛ. [BELWEDER]  Катрен г.Химки
#
#                                     DR_Prod  DR_Kol  DR_CZak  DR_CRoz  \
# 4459                        Северная Звезда    1.00   297.74   396.00
# 4460  Кадила Фармасьютикалз Лтд  ( CADILA )    1.00   322.06   419.00
# ...

# %%
df.shape
# Out:
# (4462, 21)

# %%
df.size #количество элементов в дата фрейме (4462 * 21)
# Out:
# 93702

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4462, step=1)

# %%
df.columns
# Out:
# Index(['DR_Dat', 'DR_Tim', 'DR_NChk', 'DR_NDoc', 'DR_Apt', 'DR_Kkm', 'DR_TDoc',
#        'DR_TPay', 'DR_CDrugs', 'DR_NDrugs', 'DR_Suppl', 'DR_Prod', 'DR_Kol',
#        'DR_CZak', 'DR_CRoz', 'DR_SDisc', 'DR_CDisc', 'DR_BCDisc', 'DR_TabEmpl',
#        'DR_VZak', 'DR_Pos'],
#       dtype='object')

# %%
our_cols = ['DR_Dat', 'DR_Tim', 'DR_NChk', 'DR_NDoc', 'DR_Apt', 'DR_NDrugs', 'DR_Kol',
       'DR_CZak', 'DR_CRoz', 'DR_SDisc', 'DR_TPay', 'DR_CDrugs', 'DR_Suppl', 'DR_CDisc', 'DR_BCDisc', 
        'DR_TabEmpl', 'DR_VZak', 'DR_Pos'] # меняем порядок и состав столбцов

# %%
df = df[our_cols]

# %%
df.head()
# Out:
#        DR_Dat    DR_Tim  DR_NChk  DR_NDoc  DR_Apt  \
# 0  2022-08-11  10:15:35     2173  2004598       2
# 1  2022-08-11  10:27:46     2174  2004598       2
# 2  2022-08-11  10:27:46     2174  2004598       2
# 3  2022-08-11  10:27:46     2174  2004598       2
# 4  2022-08-11  10:33:56     2175  2004598       2
#
#                                            DR_NDrugs  DR_Kol  DR_CZak  \
# 0  ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-...    1.00    41.08
# 1            ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ.    1.00    18.61
# 2  СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ...    1.00   132.69
# 3  СОФЬЯ ГХК КРЕМ Д/ТЕЛА ХОНДРОИТИН+ГЛЮКОЗАМИН 12...    1.00   133.65
# 4                   ГАЛВУС 50МГ. №28 ТАБ. /НОВАРТИС/    1.00   709.95
#
#    DR_CRoz  DR_SDisc  DR_TPay  DR_CDrugs        DR_Suppl  DR_CDisc  \
# 0    51.00     12.00       18      45399  Катрен г.Химки    925.00
# 1    31.00      3.00       15     261519  Катрен г.Химки      9.00
# ...

# %%
df.shape
# Out:
# (4462, 18)

# %%
# переименовываем столбцы
df.columns = ['dt', 'c_time', 'nchk', 'ndoc', 'apt', 'drug', 'kol',
       'zak', 'roz', 'disc', 'pay_type', 'drug_id', 'suppl', 'disc_id', 'disc_barcode', 'empl', 'vzak', 'pos']
df
# Out:
#               dt    c_time  nchk      ndoc  apt  \
# 0     2022-08-11  10:15:35  2173   2004598    2
# 1     2022-08-11  10:27:46  2174   2004598    2
# 2     2022-08-11  10:27:46  2174   2004598    2
# 3     2022-08-11  10:27:46  2174   2004598    2
# 4     2022-08-11  10:33:56  2175   2004598    2
# ...          ...       ...   ...       ...  ...
# 4457  2022-08-12  21:40:17  5690  18002542   18
# 4458  2022-08-12  21:40:59  5691  18002542   18
# 4459  2022-08-12  21:43:48  5692  18002542   18
# 4460  2022-08-12  21:44:46  5693  18002542   18
# 4461  2022-08-12  21:46:08  5694  18002542   18
#
#                                                    drug  kol    zak    roz  \
# 0     ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-... 1.00  41.08  51.00
# 1               ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ. 1.00  18.61  31.00
# 2     СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ... 1.00 132.69 209.00
# 3     СОФЬЯ ГХК КРЕМ Д/ТЕЛА ХОНДРОИТИН+ГЛЮКОЗАМИН 12... 1.00 133.65 210.00
# ...

# %%
df.dtypes
# Out:
# dt               object
# c_time           object
# nchk              int64
# ndoc              int64
# apt               int64
# drug             object
# kol             float64
# zak             float64
# roz             float64
# disc            float64
# pay_type          int64
# drug_id           int64
# suppl            object
# disc_id         float64
# disc_barcode    float64
# empl              int64
# vzak              int64
# pos             float64
# dtype: object

# %%
df['disc_barcode'].dtype
# Out:
# dtype('float64')

# %%
# меняем тип данных для 'disc_barcode'
df.loc[:, 'disc_barcode'] = df['disc_barcode'].astype('str').replace('\\.0', '', regex=True)

# %%
df.dtypes
# Out:
# dt               object
# c_time           object
# nchk              int64
# ndoc              int64
# apt               int64
# drug             object
# kol             float64
# zak             float64
# roz             float64
# disc            float64
# pay_type          int64
# drug_id           int64
# suppl            object
# disc_id         float64
# disc_barcode     object
# empl              int64
# vzak              int64
# pos             float64
# dtype: object

# %%
df
# Out:
#               dt    c_time  nchk      ndoc  apt  \
# 0     2022-08-11  10:15:35  2173   2004598    2
# 1     2022-08-11  10:27:46  2174   2004598    2
# 2     2022-08-11  10:27:46  2174   2004598    2
# 3     2022-08-11  10:27:46  2174   2004598    2
# 4     2022-08-11  10:33:56  2175   2004598    2
# ...          ...       ...   ...       ...  ...
# 4457  2022-08-12  21:40:17  5690  18002542   18
# 4458  2022-08-12  21:40:59  5691  18002542   18
# 4459  2022-08-12  21:43:48  5692  18002542   18
# 4460  2022-08-12  21:44:46  5693  18002542   18
# 4461  2022-08-12  21:46:08  5694  18002542   18
#
#                                                    drug  kol    zak    roz  \
# 0     ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-... 1.00  41.08  51.00
# 1               ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ. 1.00  18.61  31.00
# 2     СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ... 1.00 132.69 209.00
# 3     СОФЬЯ ГХК КРЕМ Д/ТЕЛА ХОНДРОИТИН+ГЛЮКОЗАМИН 12... 1.00 133.65 210.00
# ...

# %%
# меняем тип данных для 'disc_id'
df.loc[:, 'disc_id'] = df.disc_id.astype('str').replace('\\.0', '', regex=True)
df

# %%
df.dt
# Out:
# 0       2022-08-11
# 1       2022-08-11
# 2       2022-08-11
# 3       2022-08-11
# 4       2022-08-11
#            ...
# 4457    2022-08-12
# 4458    2022-08-12
# 4459    2022-08-12
# 4460    2022-08-12
# 4461    2022-08-12
# Name: dt, Length: 4462, dtype: object

# %%
pd.to_datetime(df['dt']).dt.month #day_of week, year и т.д. можем использовать разные функции при использовании .dt
# Out:
# 0       8
# 1       8
# 2       8
# 3       8
# 4       8
#        ..
# 4457    8
# 4458    8
# 4459    8
# 4460    8
# 4461    8
# Name: dt, Length: 4462, dtype: int32

# %%
df.loc[:, 'dt'] = pd.to_datetime(df['dt']).dt.strftime('%d.%m.%Y')
df
# Out:
#               dt    c_time  nchk      ndoc  apt  \
# 0     08.11.2022  10:15:35  2173   2004598    2
# 1     08.11.2022  10:27:46  2174   2004598    2
# 2     08.11.2022  10:27:46  2174   2004598    2
# 3     08.11.2022  10:27:46  2174   2004598    2
# 4     08.11.2022  10:33:56  2175   2004598    2
# ...          ...       ...   ...       ...  ...
# 4457  08.12.2022  21:40:17  5690  18002542   18
# 4458  08.12.2022  21:40:59  5691  18002542   18
# 4459  08.12.2022  21:43:48  5692  18002542   18
# 4460  08.12.2022  21:44:46  5693  18002542   18
# 4461  08.12.2022  21:46:08  5694  18002542   18
#
#                                                    drug  kol    zak    roz  \
# 0     ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-... 1.00  41.08  51.00
# 1               ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ. 1.00  18.61  31.00
# 2     СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ... 1.00 132.69 209.00
# 3     СОФЬЯ ГХК КРЕМ Д/ТЕЛА ХОНДРОИТИН+ГЛЮКОЗАМИН 12... 1.00 133.65 210.00
# ...

# %%
df.dtypes
# Out:
# dt               object
# c_time           object
# nchk              int64
# ndoc              int64
# apt               int64
# drug             object
# kol             float64
# zak             float64
# roz             float64
# disc            float64
# pay_type          int64
# drug_id           int64
# suppl            object
# disc_id          object
# disc_barcode     object
# empl              int64
# vzak              int64
# pos             float64
# dtype: object

# %%
df['vzak'].unique()
# Out:
# array([1, 2])

# %%
df.loc[:, 'vzak'] = df.vzak.astype('str').replace('1', 'Обычный').replace('2', 'Интернет')

# %%
df.head()
# Out:
#            dt    c_time  nchk     ndoc  apt  \
# 0  08.11.2022  10:15:35  2173  2004598    2
# 1  08.11.2022  10:27:46  2174  2004598    2
# 2  08.11.2022  10:27:46  2174  2004598    2
# 3  08.11.2022  10:27:46  2174  2004598    2
# 4  08.11.2022  10:33:56  2175  2004598    2
#
#                                                 drug  kol    zak    roz  disc  \
# 0  ЦИПРОЛЕТ 3МГ/МЛ. 5МЛ. №1 ГЛ.КАПЛИ ФЛ./КАП. /Д-... 1.00  41.08  51.00 12.00
# 1            ПЕРЕКИСЬ ВОДОРОДА 3% 100МЛ. №40 Р-Р ФЛ. 1.00  18.61  31.00  3.00
# 2  СОФЬЯ ГЕЛЬ Д/НОГ ВЕНОТОНИЗ. ТРОКСЕРУТИН ФОРТЕ ... 1.00 132.69 209.00 20.00
# 3  СОФЬЯ ГХК КРЕМ Д/ТЕЛА ХОНДРОИТИН+ГЛЮКОЗАМИН 12... 1.00 133.65 210.00 21.00
# 4                   ГАЛВУС 50МГ. №28 ТАБ. /НОВАРТИС/ 1.00 709.95 787.00 49.00
#
#    pay_type  drug_id           suppl disc_id  disc_barcode  empl     vzak  pos
# 0        18    45399  Катрен г.Химки     925  200000000492   205  Обычный 1.00
# ...

# %%
#оценка пропуск или нет

df.isna()
# Out:
#          dt  c_time   nchk   ndoc    apt   drug    kol    zak    roz   disc  \
# 0     False   False  False  False  False  False  False  False  False  False
# 1     False   False  False  False  False  False  False  False  False  False
# 2     False   False  False  False  False  False  False  False  False  False
# 3     False   False  False  False  False  False  False  False  False  False
# 4     False   False  False  False  False  False  False  False  False  False
# ...     ...     ...    ...    ...    ...    ...    ...    ...    ...    ...
# 4457  False   False  False  False  False  False  False  False  False  False
# 4458  False   False  False  False  False  False  False  False  False  False
# 4459  False   False  False  False  False  False  False  False  False  False
# 4460  False   False  False  False  False  False  False  False  False  False
# 4461  False   False  False  False  False  False  False  False  False  False
#
# ...

# %%
df.isna().any() #проверяем есть ли хотя бы один пропуск
# Out:
# dt              False
# c_time          False
# nchk            False
# ndoc            False
# apt             False
# drug            False
# kol             False
# zak             False
# roz             False
# disc            False
# pay_type        False
# drug_id         False
# suppl           False
# disc_id         False
# disc_barcode    False
# empl            False
# vzak            False
# pos             False
# dtype: bool

# %%
df.isna().all() # проверяет, все ли значения с пропусками
# Out:
# dt              False
# c_time          False
# nchk            False
# ndoc            False
# apt             False
# drug            False
# kol             False
# zak             False
# roz             False
# disc            False
# pay_type        False
# drug_id         False
# suppl           False
# disc_id         False
# disc_barcode    False
# empl            False
# vzak            False
# pos             False
# dtype: bool

# %%
df2 = pd.read_csv('data_And.csv', encoding='1251')
df2
# Out:
#           DR_Dat    DR_Tim  DR_NChk   DR_NDoc  DR_Apt  DR_Kkm  \
# 0     2022-08-11  10:15:35     2173   2004598       2   22577
# 1     2022-08-11  10:27:46     2174   2004598       2   22577
# 2     2022-08-11  10:27:46     2174   2004598       2   22577
# 3     2022-08-11  10:27:46     2174   2004598       2   22577
# 4     2022-08-11  10:33:56     2175   2004598       2   22577
# ...          ...       ...      ...       ...     ...     ...
# 4457  2022-08-12  21:40:17     5690  18002542      18    9907
# 4458  2022-08-12  21:40:59     5691  18002542      18    9907
# 4459  2022-08-12  21:43:48     5692  18002542      18    9907
# 4460  2022-08-12  21:44:46     5693  18002542      18    9907
# 4461  2022-08-12  21:46:08     5694  18002542      18    9907
#
#                    DR_TDoc  DR_TPay  DR_CDrugs  \
# 0     Розничная реализация       18      45399
# 1     Розничная реализация       15     261519
# 2     Розничная реализация       15     460864
# ...

# %%
df2.isna().any()
# Out:
# DR_Dat        False
# DR_Tim        False
# DR_NChk       False
# DR_NDoc       False
# DR_Apt        False
# DR_Kkm        False
# DR_TDoc       False
# DR_TPay       False
# DR_CDrugs     False
# DR_NDrugs     False
# DR_Suppl      False
# DR_Prod       False
# DR_Kol        False
# DR_CZak       False
# DR_CRoz       False
# DR_SDisc      False
# DR_CDisc       True
# DR_BCDisc      True
# DR_TabEmpl    False
# DR_VZak       False
# DR_Pos        False
# dtype: bool

# %%
df2.fillna(0).isna().any() #заполняем пропуски нулями
# Out:
# DR_Dat        False
# DR_Tim        False
# DR_NChk       False
# DR_NDoc       False
# DR_Apt        False
# DR_Kkm        False
# DR_TDoc       False
# DR_TPay       False
# DR_CDrugs     False
# DR_NDrugs     False
# DR_Suppl      False
# DR_Prod       False
# DR_Kol        False
# DR_CZak       False
# DR_CRoz       False
# DR_SDisc      False
# DR_CDisc      False
# DR_BCDisc     False
# DR_TabEmpl    False
# DR_VZak       False
# DR_Pos        False
# dtype: bool

# %%
df2.isna()
# Out:
#       DR_Dat  DR_Tim  DR_NChk  DR_NDoc  DR_Apt  DR_Kkm  DR_TDoc  DR_TPay  \
# 0      False   False    False    False   False   False    False    False
# 1      False   False    False    False   False   False    False    False
# 2      False   False    False    False   False   False    False    False
# 3      False   False    False    False   False   False    False    False
# 4      False   False    False    False   False   False    False    False
# ...      ...     ...      ...      ...     ...     ...      ...      ...
# 4457   False   False    False    False   False   False    False    False
# 4458   False   False    False    False   False   False    False    False
# 4459   False   False    False    False   False   False    False    False
# 4460   False   False    False    False   False   False    False    False
# 4461   False   False    False    False   False   False    False    False
#
#       DR_CDrugs  DR_NDrugs  DR_Suppl  DR_Prod  DR_Kol  DR_CZak  DR_CRoz  \
# ...

# %%
df2.isna().values
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]], shape=(4462, 21))

# %%
df2.isna().values.any()
# Out:
# np.True_

# %%
df2.isna().values.any(axis=0) #показывается наличие хотя бы одного пропуска в каждом столбце
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True,  True,
#        False, False, False])

# %%
df2.isna().values.any(axis=1) #показывается наличие хотя бы одного пропуска в каждой строке
# Out:
# array([False, False, False, ...,  True,  True, False], shape=(4462,))

# %%
df3 = df2[df2.isna().values.any(axis=1)]
df3
# Out:
#           DR_Dat    DR_Tim  DR_NChk   DR_NDoc  DR_Apt  DR_Kkm  \
# 15    2022-08-11  11:00:23     2178   2004598       2   22577
# 16    2022-08-11  11:00:23     2178   2004598       2   22577
# 20    2022-08-11  11:31:34     2181   2004598       2   22577
# 21    2022-08-11  11:31:34     2181   2004598       2   22577
# 22    2022-08-11  11:36:05     2182   2004598       2   22577
# ...          ...       ...      ...       ...     ...     ...
# 4456  2022-08-12  21:39:23     5689  18002542      18    9907
# 4457  2022-08-12  21:40:17     5690  18002542      18    9907
# 4458  2022-08-12  21:40:59     5691  18002542      18    9907
# 4459  2022-08-12  21:43:48     5692  18002542      18    9907
# 4460  2022-08-12  21:44:46     5693  18002542      18    9907
#
#                    DR_TDoc  DR_TPay  DR_CDrugs  \
# 15    Розничная реализация       18     496504
# 16    Розничная реализация       18     496504
# 20    Розничная реализация       18      14120
# ...

# %%
df3.fillna(0).head(5)[['DR_CDisc']]
# Out:
#     DR_CDisc
# 15      0.00
# 16      0.00
# 20      0.00
# 21      0.00
# 22      0.00

# %%
df2['DR_CDisc'].interpolate(method='linear')
# Out:
# 0      925.00
# 1        9.00
# 2        9.00
# 3        9.00
# 4      925.00
#         ...
# 4457     9.00
# 4458     9.00
# 4459     9.00
# 4460     9.00
# 4461     9.00
# Name: DR_CDisc, Length: 4462, dtype: float64

# %%
df2.shape
# Out:
# (4462, 21)

# %%
df2.dropna().shape # удаляются строки, в которых есть хотя бы 1 пропуск
# Out:
# (1765, 21)

# %%
df2.dropna(axis=1).shape #удаляются столбцы с пропусками
# Out:
# (4462, 19)

# %%
3 способа борьбы с пропусками:
 - заполнение фиксированными значениями
 - интерполяция
 - удаление

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined
