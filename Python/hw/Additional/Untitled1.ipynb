# %%
import pandas as pd

# %%
# Загрузка с явным указанием типа данных для CONTACTID как строка
dtype_dict = {
    'Id': 'str',
    'Contact Name': 'str'
}

# Загружаем Excel
excel_file_calls = pd.read_excel('Deals (Done)_for_test.xlsx', dtype=dtype_dict)

excel_file_calls.to_csv("Deals_for_test.xlsx.csv", index=False, encoding='utf-8-sig')

# %%
deals_df = pd.read_csv("Deals_for_test.xlsx.csv", dtype=dtype_dict)
deals_df
# Out:
#                         Id Deal Owner Name Closing Date            Quality  \
# 0      5805028000056864695        Ben Hall          NaN                NaN
# 1      5805028000056859489   Ulysses Adams          NaN                NaN
# 2      5805028000056832357   Ulysses Adams   21.06.2024     D - Non Target
# 3      5805028000056824246        Eva Kent   21.06.2024  E - Non Qualified
# 4      5805028000056873292        Ben Hall   21.06.2024     D - Non Target
# ...                    ...             ...          ...                ...
# 21590  5805028000000945016      Jane Smith   29.08.2023           A - High
# 21591  5805028000000927004       Bob Brown   09.07.2023     D - Non Target
# 21592  5805028000000922001       Bob Brown   03.07.2023  E - Non Qualified
# 21593                  NaN             NaN          NaN                NaN
# 21594                  NaN             NaN          NaN                NaN
#
#           Stage             Lost Reason                   Page  \
# ...

# %%
deals_df[deals_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Id, Deal Owner Name, Closing Date, Quality, Stage, Lost Reason, Page, Campaign, SLA, Content, Term, Source, Payment Type, Product, Education Type, Created Time, Course duration, Months of study, Initial Amount Paid, Offer Total Amount, Contact Name, City, Level of Deutsch]
# Index: []
#
# [0 rows x 23 columns]
