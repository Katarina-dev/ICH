# %%
Визуализация с
помощью seaborn

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [raw]
# distplot (displot и histplot) — это функция, которая позволяет визуализировать
# распределение переменной, включая гистограмму и KDE
# (ядерная оценка плотности).

# %%
x = np.random.randn(100) #нормальное случайное распределение
sns.histplot(x, kde=True)
plt.show()

# %%
jointplot — это функция, которая создает многопанельный график,
показывающий распределения двух переменных и их
взаимосвязь.

# %%
data = pd.DataFrame({'x': np.random.randn(100), 'y': np.random.randn(100)})
sns.jointplot(x='x', y='y', data=data, kind='scatter')
plt.show()

# %%
kdeplot — это функция, которая позволяет визуализировать
распределение данных с помощью ядерной оценки
плотности, включая многомерные распределения.

# %%
# Load the tips dataset
tips = sns.load_dataset("tips") # читает датасет изнутри библиотеки
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [raw]
# total_bill: Общая сумма счета (включая чаевые) в долларах.
# tip: Сумма чаевых в долларах.
# sex: Пол официанта, обслуживавшего столик (Male или Female).
# smoker: Указывает, курящий столик или нет (Yes или No).
# day: День недели, когда была получена чаевые (Thur, Fri, Sat, Sun).
# time: Время дня, когда была получена чаевые (Lunch или Dinner).
# size: Количество людей, сидящих за столиком.

# %%
sns.kdeplot(data=tips, x="total_bill", y="tip", hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
x = np.random.randn(100)
sns.displot(x, kde=True)
plt.show()
sns.histplot(x, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [raw]
# barplot — это график, который показывает среднее значение по
# категориям с помощью столбцов и дает понимание о
# дисперсии данных через ошибки.

# %%
tips = sns.load_dataset("tips")
sns.barplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [raw]
# boxplot — это график, который визуализирует распределение
# категориальных данных и выделяет выбросы.

# %%
sns.boxplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
черта - медиана
низ бокса - квантиль 25
верх бокса - квантиль 75
====
следовательно ширина бокса 50% данных

длина уса == 1.5 ширины бокса
выбросы == то, что не попало в усы

# %% [raw]
# scatterplot — это функция, которая позволяет реализовать классический
# способ для визуализации взаимосвязи между двумя
# непрерывными переменными.

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, hue='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
lineplot — это функция, которая полезна для визуализации временных
рядов или зависимостей между двумя непрерывными
переменными.

# %%
sns.lineplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
pairplot — это функция, которая отображает попарные отношения в
наборе данных и распределение каждой переменной на
диагонали.

# %%
sns.pairplot(tips)

# %%
heatmap — это функция, которая позволяет визуализировать
матрицы корреляции или других двумерных данных.

# %%
corr = tips.select_dtypes(include=['number']).corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
regplot и lmplot — это функции, которые позволяют визуализировать
линейную зависимость между двумя переменными и
оценить регрессионную модель.

# %%
sns.regplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [raw]
# FacetGrid — это функция, которая позволяет построить решетку
# графиков, основанную на распределении категориальной
# переменной. Это полезно для сравнения подгрупп данных.

# %%
g = sns.FacetGrid(tips, col="time", row="smoker") # переборка значений
g.map(sns.scatterplot, "total_bill", "tip")

# %%
g = sns.FacetGrid(tips, col="time", row="sex") # переборка значений
g.map(sns.scatterplot, "total_bill", "tip")

# %%
catplot — это функция, которая используется для построения
различных типов категориальных графиков, включая
точечные, столбчатые и скрипичные диаграммы.

# %%
sns.catplot(x="day", y="total_bill", hue="smoker", kind="violin", data=tips)

# %%
sns.set_style("whitegrid")
sns.set_context("talk")
sns.regplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_context("notebook")
sns.regplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style("white")
sns.set_context("talk")
sns.regplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [raw]
# set_theme — это функция, которая используется для настройки
# глобального внешнего вида всех графиков.

# %%
sns.set_theme(style="darkgrid")
sns.regplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
palette — это функция-параметр в функциях визуализации для
выбора схемы цветов.

# %%
sns.set_palette("pastel")
sns.regplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_palette("spring")
sns.regplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [raw]
# sns.palplot — это функция, которая позволяет визуализировать
# используемую палитру.

# %%
#Последовательные (sequential)
sns.palplot(sns.color_palette('viridis', n_colors=10))
sns.palplot(sns.color_palette('magma', n_colors=10))
sns.palplot(sns.color_palette('inferno', n_colors=10))

# %%
#Расходящиеся (diverging)
sns.palplot(sns.color_palette('coolwarm', n_colors=10))
sns.palplot(sns.color_palette('rainbow', n_colors=10))

# %%
#Категориальные (qualitative)
sns.palplot(sns.color_palette('muted', n_colors=10))
sns.palplot(sns.color_palette('Set2', n_colors=20))

# %%
# Установка эстетических параметров графиков
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1,
color_codes=False, rc=None)
sns.regplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
def sinplot(): # функция синуса
    x = np.linspace(0, 20, 100)
    plt.plot(x, np.sin(x))

plt.figure(figsize=(15, 9))
for i, context in enumerate(['notebook', 'paper', 'talk', 'poster']):
 sns.set(context=context) # Устанавливаем стиль
 plt.subplot(2, 2, i+1)
 sinplot()
 plt.title(context)

# %%
sns.set(style='white')
sinplot()
sns.despine() #убирает рамк

# %%
sns.set(style='white')
sinplot()

# %%
fig, ax = plt.subplots()
sns.scatterplot(x="total_bill", y="tip", ax=ax, data=tips)
ax.set_title("Scatterplot in Matplotlib Figure")
# Out:
# Text(0.5, 1.0, 'Scatterplot in Matplotlib Figure')

# %% [raw]
# 1. Рассмотрим датасет "Ирисы Фишера". Этот датасет содержит информацию о 150 экземплярах ириса,
# разделенных на три вида: Setosa, Versicolor и Virginica. Для каждого экземпляра ириса зарегистрированы
# четыре атрибута: длина и ширина чашелистика, длина и ширина лепестка. Визуализируйте распределение
# длины лепестков.

# %%
df = sns.load_dataset('iris')
sns.histplot(data=df, x='petal_length', hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [raw]
# 2. Сравните длины и ширины чашелистика с использованием scatterplot.

# %%
sns.scatterplot(data=df, x='sepal_width', y ='sepal_length' , hue='species')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %% [raw]
# Box plot — это график, использующийся в описательной статистике,
# компактно изображающий одномерное распределение
# вероятностей.

# %%
data = np.random.normal(size=(1000, 6)) + np.arange(6) / 2
data
# Out:
# array([[-0.0199821 ,  1.52583797,  0.59457824, -0.38735807,  2.66525812,
#          4.47872383],
#        [-0.62956028, -0.30439404,  0.65566249, -0.81706896,  2.65469348,
#          2.07523017],
#        [-0.76160828,  1.48095195,  0.39831676,  2.57345986,  0.97396899,
#          2.90693349],
#        ...,
#        [ 0.76738545,  1.43211834,  0.18924991,  2.6207623 ,  0.21813082,
#          1.6835514 ],
#        [-0.10424764, -1.71968487, -0.82058268,  0.15156714,  3.06785839,
#          3.05720147],
#        [ 0.12472576, -0.73373702,  1.64909588,  2.28703079,  2.1019938 ,
#          3.20280979]], shape=(1000, 6))

# %%
plt.figure(figsize=(8, 7))
sns.boxplot(data=data, palette='Set2');

# %%
plt.figure(figsize=(15, 6))
plt.subplot(121)
sns.boxplot(x='day', y='total_bill', data=tips, palette='Set3')
plt.ylabel('Сумма счета')
plt.subplot(122)
sns.boxplot(x='day', y='tip', data=tips, palette='Set3')
plt.ylabel('Размер чаевых');
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18452\3157989598.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day', y='total_bill', data=tips, palette='Set3')
# C:\Users\user\AppData\Local\Temp\ipykernel_18452\3157989598.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day', y='tip', data=tips, palette='Set3')

# %%
plt.figure(figsize=(15, 6))
plt.subplot(121)
ax = sns.boxplot(x='day', y='total_bill', hue='sex',
 data=tips, palette='Set3')
ax.legend().get_frame().set_facecolor("white")
plt.ylabel('Сумма счета')
plt.subplot(122)
ax = sns.boxplot(x='day', y='tip', hue='sex',
 data=tips, palette='Set3')
ax.legend().get_frame().set_facecolor("white")
plt.ylabel('Размер чаевых');

tips.describe()
# len(tips['day'].unique()) # находим кол-во уникальных значений
len(tips.day.unique()) # находим кол-во уникальных значений
# Out:
# 4

# %% [raw]
# Violin plot — это комбинация boxplot и ядерной оценки плотности.
# Внутри облака изображен обычный ящик с усами, только в
# сжатом виде и без выбросов. Форма облака соответствует
# ядерной оценке плотности.

# %%
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
plt.figure(figsize=(8, 7))
sns.violinplot(data=data, palette='Set2', bw=.2, cut=1, linewidth=1);
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18452\4122281655.py:3: FutureWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method`/`bw_adjust`.
# Setting `bw_method=0.2`, but please see docs for the new parameters
# and update your code. This will become an error in seaborn v0.15.0.
#
#   sns.violinplot(data=data, palette='Set2', bw=.2, cut=1, linewidth=1);

# %%
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
plt.figure(figsize=(8, 7))
sns.violinplot(data=data, palette='Set2')
# Out:
# <Axes: >

# %%
with sns.plotting_context("notebook", font_scale=1.5):
 plt.figure(figsize=(8, 7))
 sns.violinplot(x="day", y="tip", hue="smoker",
 data=tips, palette="Set2", split=True);
 plt.ylabel('Размер чаевых');
 plt.xlabel('День недели');

# %% [raw]
# Heatmap — это инструмент, который визуализирует двумерную
# таблицу в виде тепловой карты.
#
# data — 2D-данные
# ● vmin и vmax — минимальное и максимальное значения цветов
# ● cmap — цветовая схема
# ● robust — если не указаны vmin и vmax, то не используются выбросы при определении минимума и максимума
# ● annot — в какие ячейки записывать данные
# ● fmt — формат записи данных
# ● linewidths — ширина линий между ячейками
# ● linecolor — цвет линий между ячейками
# ● cbar — рисовать ли colorbar

# %%
flights_long = sns.load_dataset('flights')
flights_long.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights = flights_long.pivot_table(index='month',
                                 columns='year',
                                 values='passengers')
flights
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18452\666025051.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights = flights_long.pivot_table(index='month',
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# ...

# %%
# sns.set(font_scale=1.3)
f, ax = plt.subplots(figsize=(12, 7))
sns.heatmap(flights, annot=True, fmt='.0f', ax=ax, cmap="viridis")
plt.ylim((0, 12));

# %% [raw]
# Clustermap — это аналог sns.heatmap, который автоматически
# группирует похожие строки и/или столбцы таблицы.

# %%
data = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)
# выберем подмножество отделов мозга
used_networks = [1, 5, 6, 7, 8, 12, 13, 17]
used_columns = (data.columns.get_level_values("network")
 .astype(int)
 .isin(used_networks))
data = data.loc[:, used_columns]
# создадим для них категориальную палитру
network_pal = sns.husl_palette(len(used_networks), s=.45)
network_lut = dict(zip(map(str, used_networks), network_pal))
# окрасим строки и столбцы в соответствии с отделом
networks = data.columns.get_level_values("network")
network_colors = pd.Series(networks, index=data.columns).map(network_lut)
# нарисуем график корреляции паттернов активности участков мозга
# и убедимся, что участки из одного отдела попадают в одну группу
# после иерархической кластеризации
sns.clustermap(data.corr(), center=0, cmap="vlag",
 row_colors=network_colors, col_colors=network_colors,
 linewidths=.75, figsize=(13, 13));

# %% [raw]
# Рассмотрим датасет "Ирисы Фишера". Этот датасет содержит информацию о 150 экземплярах ириса,
# разделенных на три вида: Setosa, Versicolor и Virginica. Для каждого экземпляра ириса зарегистрированы
# четыре атрибута: длина и ширина чашелистика, длина и ширина лепестка. Сравните распределение всех
# четырех характеристик (длина и ширина чашелистика, длина и ширина лепестка) между разными видами
# ирисов с использованием violinplot.

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df = sns.load_dataset('iris')
df2 = df.melt(id_vars = 'species')
df2
# Out:
#        species      variable  value
# 0       setosa  sepal_length    5.1
# 1       setosa  sepal_length    4.9
# 2       setosa  sepal_length    4.7
# 3       setosa  sepal_length    4.6
# 4       setosa  sepal_length    5.0
# ..         ...           ...    ...
# 595  virginica   petal_width    2.3
# 596  virginica   petal_width    1.9
# 597  virginica   petal_width    2.0
# 598  virginica   petal_width    2.3
# 599  virginica   petal_width    1.8
#
# [600 rows x 3 columns]

# %%
sns.violinplot(data = df2, x='variable', hue='species', y='value')
# Out:
# <Axes: xlabel='variable', ylabel='value'>

# %%
# ?df.melt
# Out:
# Signature:
# df.melt(
#     id_vars=None,
#     value_vars=None,
#     var_name=None,
#     value_name: 'Hashable' = 'value',
#     col_level: 'Level | None' = None,
#     ignore_index: 'bool' = True,
# ) -> 'DataFrame'
# Docstring:
# Unpivot a DataFrame from wide to long format, optionally leaving identifiers set.
#
# This function is useful to massage a DataFrame into a format where one
# or more columns are identifier variables (`id_vars`), while all other
# columns, considered measured variables (`value_vars`), are "unpivoted" to
# the row axis, leaving just two non-identifier columns, 'variable' and
# 'value'.
#
# Parameters
# ----------
# id_vars : scalar, tuple, list, or ndarray, optional
#     Column(s) to use as identifier variables.
# value_vars : scalar, tuple, list, or ndarray, optional
#     Column(s) to unpivot. If not specified, uses all columns that
#     are not set as `id_vars`.
# var_name : scalar, default None
# ...
