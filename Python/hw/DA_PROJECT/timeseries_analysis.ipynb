# %% [markdown]
# # Анализ временных рядов

# %% [markdown]
# ## 1. Проанализируйте тенденцию создания сделок с течением времени и их связь с звонками.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.datasets import get_rdataset

deals_df = pd.read_pickle("deals_cleaned_v3.pkl")

deals_df.set_index('Created Time', inplace=True)
deals_df.head()
# Out:
#                                       Id Deal Owner Name Closing Date  \
# Created Time
# 2024-06-21 15:30:00  5805028000056864695        Ben Hall          NaT
# 2024-06-21 15:23:00  5805028000056859489   Ulysses Adams          NaT
# 2024-06-21 14:45:00  5805028000056832357   Ulysses Adams   2024-06-21
# 2024-06-21 13:32:00  5805028000056824246        Eva Kent   2024-06-21
# 2024-06-21 13:21:00  5805028000056873292        Ben Hall   2024-06-21
#
#                                Quality     Stage     Lost Reason       Page  \
# Created Time
# 2024-06-21 15:30:00         B - Medium  New Lead             NaN  /eng/test
# 2024-06-21 15:23:00         B - Medium  New Lead             NaN    /at-eng
# 2024-06-21 14:45:00     D - Non Target      Lost      Non target    /at-eng
# 2024-06-21 13:32:00  E - Non Qualified      Lost  Invalid number       /eng
# 2024-06-21 13:21:00     D - Non Target      Lost      Non target       /eng
#
#                                      Campaign             SLA  \
# Created Time
# 2024-06-21 15:30:00             03.07.23women             NaT
# 2024-06-21 15:23:00                       NaN             NaT
# 2024-06-21 14:45:00                engwien_at 0 days 00:26:43
# 2024-06-21 13:32:00  04.07.23recentlymoved_de 0 days 01:00:04
# 2024-06-21 13:21:00              discovery_de 0 days 00:53:12
#
#                                 Content  ... Course duration Months of study  \
# Created Time                             ...
# 2024-06-21 15:30:00                 v16  ...             NaN            <NA>
# 2024-06-21 15:23:00                 NaN  ...               6            <NA>
# 2024-06-21 14:45:00               b1-at  ...             NaN            <NA>
# 2024-06-21 13:32:00  bloggersvideo14com  ...             NaN            <NA>
# 2024-06-21 13:21:00             website  ...             NaN            <NA>
#
#                     Initial Amount Paid Offer Total Amount  \
# Created Time
# 2024-06-21 15:30:00                 NaN                NaN
# 2024-06-21 15:23:00                 NaN             2000.0
# 2024-06-21 14:45:00                 NaN                NaN
# 2024-06-21 13:32:00                 NaN                NaN
# 2024-06-21 13:21:00                 NaN                NaN
#
#                             Contact Name City  Level of Deutsch  Created Date  \
# Created Time
# 2024-06-21 15:30:00  5805028000056849495  NaN               NaN    2024-06-21
# 2024-06-21 15:23:00  5805028000056834471  NaN               NaN    2024-06-21
# 2024-06-21 14:45:00  5805028000056854421  NaN               NaN    2024-06-21
# 2024-06-21 13:32:00  5805028000056889351  NaN               NaN    2024-06-21
# 2024-06-21 13:21:00  5805028000056876176  NaN               NaN    2024-06-21
#
#                      Create_to_Close_Days            SLA_range
# Created Time
# 2024-06-21 15:30:00                   NaN                  NaN
# 2024-06-21 15:23:00                   NaN                  NaN
# 2024-06-21 14:45:00                   0.0   Medium (15-30 min)
# 2024-06-21 13:32:00                   0.0  Very slow (>60 min)
# 2024-06-21 13:21:00                   0.0     Slow (30-60 min)
#
# [5 rows x 25 columns]

# %%
# Sort by Created Time
deals_df.sort_index(inplace=True)

# %%
# Check results
print(deals_df.index[:5])
print(deals_df.index[-5:])
# Out:
# DatetimeIndex(['2023-07-03 17:03:00', '2023-07-03 20:17:00',
#                '2023-07-03 20:39:00', '2023-07-04 07:10:00',
#                '2023-07-04 07:10:00'],
#               dtype='datetime64[ns]', name='Created Time', freq=None)
# DatetimeIndex(['2024-06-21 13:21:00', '2024-06-21 13:32:00',
#                '2024-06-21 14:45:00', '2024-06-21 15:23:00',
#                '2024-06-21 15:30:00'],
#               dtype='datetime64[ns]', name='Created Time', freq=None)

# %%
# Aggregate: count the number of transactions each day
daily_deals = deals_df.resample("D").size()  # time series by days
# Decomposition of the time series (period - 30, if we think that there is monthly seasonality)
decomposition = seasonal_decompose(daily_deals, model='additive', period=30)

# Extract the components
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(12, 8))
plt.suptitle('Time Series Decomposition: Daily All Deals', fontsize=16) 
plt.subplot(411)
plt.plot(daily_deals, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal, label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# Filter only successful transactions
successful_df = deals_df[deals_df['Stage'] == 'Payment Done']
successful_df.head()
# Out:
#                                       Id Deal Owner Name Closing Date  \
# Created Time
# 2023-07-04 10:11:00  5805028000000947046   Oliver Taylor   2023-07-12
# 2023-07-08 08:56:00  5805028000001401001   Oliver Taylor   2023-07-16
# 2023-07-15 13:27:00  5805028000001885076      Jane Smith   2023-08-31
# 2023-07-17 18:02:00  5805028000001987082    Julia Nelson   2023-07-17
# 2023-07-18 21:11:00  5805028000002302112    Julia Nelson   2023-07-19
#
#                         Quality         Stage                  Lost Reason  \
# Created Time
# 2023-07-04 10:11:00  B - Medium  Payment Done                          NaN
# 2023-07-08 08:56:00  B - Medium  Payment Done                          NaN
# 2023-07-15 13:27:00    A - High  Payment Done                          NaN
# 2023-07-17 18:02:00     C - Low  Payment Done  Conditions are not suitable
# 2023-07-18 21:11:00     C - Low  Payment Done                    Expensive
#
#                                       Page                           Campaign  \
# Created Time
# 2023-07-04 10:11:00  eng/digital-marketing                    02.07.23wide_de
# 2023-07-08 08:56:00  eng/digital-marketing                    02.07.23wide_de
# 2023-07-15 13:27:00  eng/digital-marketing           04.07.23recentlymoved_de
# 2023-07-17 18:02:00  eng/digital-marketing                  12.07.2023wide_de
# 2023-07-18 21:11:00  eng/digital-marketing  performancemax_digitalmarkt_ru_de
#
#                                  SLA          Content  ... Course duration  \
# Created Time                                           ...
# 2023-07-04 10:11:00 71 days 00:46:22               b3  ...              11
# 2023-07-08 08:56:00  0 days 02:22:36               b3  ...              11
# 2023-07-15 13:27:00  0 days 00:13:31               b2  ...              11
# 2023-07-17 18:02:00  0 days 00:49:16            v3com  ...              11
# 2023-07-18 21:11:00  0 days 15:24:52  _{region_name}_  ...               6
#
#                     Months of study Initial Amount Paid Offer Total Amount  \
# Created Time
# 2023-07-04 10:11:00              11              1000.0            11000.0
# 2023-07-08 08:56:00               8              1000.0            11500.0
# 2023-07-15 13:27:00              11               450.0             4000.0
# 2023-07-17 18:02:00              11              1000.0            11000.0
# 2023-07-18 21:11:00               2              1000.0             5000.0
#
#                             Contact Name        City  Level of Deutsch  \
# Created Time
# 2023-07-04 10:11:00  5805028000000939010     Hamburg               NaN
# 2023-07-08 08:56:00  5805028000001350049         NaN               NaN
# 2023-07-15 13:27:00  5805028000001880249  Ingolstadt               NaN
# 2023-07-17 18:02:00  5805028000001986077         NaN                B1
# 2023-07-18 21:11:00  5805028000002302109   Wolfsburg                B1
#
#                      Created Date  Create_to_Close_Days            SLA_range
# Created Time
# 2023-07-04 10:11:00    2023-07-04                   8.0  Very slow (>60 min)
# 2023-07-08 08:56:00    2023-07-08                   8.0  Very slow (>60 min)
# 2023-07-15 13:27:00    2023-07-15                  47.0      Fast (5-15 min)
# 2023-07-17 18:02:00    2023-07-17                   0.0     Slow (30-60 min)
# 2023-07-18 21:11:00    2023-07-18                   1.0  Very slow (>60 min)
#
# [5 rows x 25 columns]

# %%
# Group by days and count the number of successful transactions
daily_success_deals = successful_df.resample("D").count()['Id']  # Series

# Decomposition of the time series (for example, with monthly seasonality)
decomposition = seasonal_decompose(daily_success_deals, model='additive', period=30)

# Extract the components
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Vizualization
plt.figure(figsize=(12, 8))
plt.suptitle('Time Series Decomposition: Daily Success Deals', fontsize=16) 
plt.subplot(411)
plt.plot(daily_deals, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal, label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# Aggregate sales by month
monthly_sales = successful_df['Initial Amount Paid'].resample('ME').sum()

plt.figure(figsize=(10, 6))
plt.plot(monthly_sales, label='Monthly Success Deals')
plt.title('Monthly Sales')
plt.xlabel('Date')
plt.ylabel('Deals')
plt.legend()
plt.show()

# %%
# Aggregate sales by week
weekly_sales = successful_df['Initial Amount Paid'].resample('W').sum()

plt.figure(figsize=(10, 6))
plt.plot(weekly_sales, label='Weekly Deals')
plt.title('Weekly Success Deals')
plt.xlabel('Date')
plt.ylabel('Deals')
plt.legend()
plt.show()

# %%
calls_df = pd.read_pickle("calls_cleaned_v1.pkl")
calls_df = calls_df.set_index('Call Start Time')
calls_df
# Out:
#                                       Id Call Owner Name            CONTACTID  \
# Call Start Time
# 2023-06-30 08:43:00  5805028000000805001        John Doe                  NaN
# 2023-06-30 08:46:00  5805028000000768006        John Doe                  NaN
# 2023-06-30 08:59:00  5805028000000764027        John Doe                  NaN
# 2023-06-30 09:20:00  5805028000000787003        John Doe  5805028000000645014
# 2023-06-30 09:30:00  5805028000000768019        John Doe  5805028000000645014
# ...                                  ...             ...                  ...
# 2024-06-21 15:30:00  5805028000056889515   Ulysses Adams  5805028000056564231
# 2024-06-21 15:30:00  5805028000056875317   Victor Barnes  5805028000054867023
# 2024-06-21 15:30:00  5805028000056832495    Kevin Parker  5805028000010617278
# 2024-06-21 15:30:00  5805028000056893619   Victor Barnes  5805028000056839048
# 2024-06-21 15:31:00  5805028000056893631        John Doe                  NaN
#
#                     Call Type  Call Duration (in seconds)         Call Status  \
# Call Start Time
# 2023-06-30 08:43:00   Inbound                         171            Received
# 2023-06-30 08:46:00  Outbound                          28    Attended Dialled
# 2023-06-30 08:59:00  Outbound                          24    Attended Dialled
# 2023-06-30 09:20:00  Outbound                           6    Attended Dialled
# 2023-06-30 09:30:00  Outbound                          11    Attended Dialled
# ...                       ...                         ...                 ...
# 2024-06-21 15:30:00  Outbound                           6    Attended Dialled
# 2024-06-21 15:30:00  Outbound                           8    Attended Dialled
# 2024-06-21 15:30:00  Outbound                           5    Attended Dialled
# 2024-06-21 15:30:00  Outbound                           0  Unattended Dialled
# 2024-06-21 15:31:00    Missed                           0              Missed
#
#                     Outgoing Call Status  Scheduled in CRM  Call Data  \
# Call Start Time
# 2023-06-30 08:43:00                  NaN             False 2023-06-30
# 2023-06-30 08:46:00            Completed             False 2023-06-30
# 2023-06-30 08:59:00            Completed             False 2023-06-30
# 2023-06-30 09:20:00            Completed             False 2023-06-30
# 2023-06-30 09:30:00            Completed             False 2023-06-30
# ...                                  ...               ...        ...
# 2024-06-21 15:30:00            Completed             False 2024-06-21
# 2024-06-21 15:30:00            Completed             False 2024-06-21
# 2024-06-21 15:30:00            Completed             False 2024-06-21
# 2024-06-21 15:30:00            Completed             False 2024-06-21
# 2024-06-21 15:31:00                  NaN             False 2024-06-21
#
#                     Start Time Of Call Call Duration Range
# Call Start Time
# 2023-06-30 08:43:00           08:43:00             1–3 min
# 2023-06-30 08:46:00           08:46:00           15–60 sec
# 2023-06-30 08:59:00           08:59:00           15–60 sec
# 2023-06-30 09:20:00           09:20:00            3–15 sec
# 2023-06-30 09:30:00           09:30:00            3–15 sec
# ...                                ...                 ...
# 2024-06-21 15:30:00           15:30:00            3–15 sec
# 2024-06-21 15:30:00           15:30:00            3–15 sec
# 2024-06-21 15:30:00           15:30:00            3–15 sec
# 2024-06-21 15:30:00           15:30:00               0 sec
# 2024-06-21 15:31:00           15:31:00               0 sec
#
# [95874 rows x 11 columns]

# %%
filtered_calls_df = calls_df[
    (calls_df['Call Duration Range'] != '0 sec') &
    (calls_df['Call Duration Range'] != '1–3 sec')
]

# %%
inbound_filtered_calls_df = filtered_calls_df[filtered_calls_df['Call Type'] == 'Inbound']

# %%
outbound_filtered_calls_df = filtered_calls_df[filtered_calls_df['Call Type'] == 'Outbound']

# %%
outbound_filtered_calls_df['Call Type'].nunique()
# Out:
# 1

# %%
inbound_filtered_calls_df['Call Type'].nunique()
# Out:
# 1

# %%
# If there is a column with a date and it is in the index, then we simply count the rows (calls) by week:
weekly_in_calls = inbound_filtered_calls_df.resample('W').size()

plt.figure(figsize=(10, 6))
plt.plot(weekly_in_calls.index, weekly_in_calls.values, marker='o', label='Incoming calls')
plt.title('Dynamics of weekly Incoming calls')
plt.xlabel('Date')
plt.ylabel('Quantity')
plt.grid(True)
plt.legend()
plt.show()

# %%
weekly_success_deals = successful_df.resample("W").count()['Id']  # Series

plt.figure(figsize=(14, 5))
plt.plot(weekly_success_deals, label='Deals')
plt.plot(weekly_in_calls, label='Incoming calls')
plt.title('Deals and Incoming calls by weeks')
plt.xlabel('Date')
plt.ylabel('Quantity')
plt.legend()
plt.show()

# %%
# Combine data by date
correlation_df = pd.DataFrame({
    'calls': weekly_in_calls,
    'deals': weekly_success_deals
}).dropna()

# Calculate the Pearson correlation coefficient
correlation = correlation_df['calls'].corr(correlation_df['deals'], method='pearson')

print(f"Pearson correlation coefficient between Incoming calls (>3 sec) and deals: {correlation:.3f}")
# Out:
# Pearson correlation coefficient between Incoming calls (>3 sec) and deals: 0.524

# %%
weekly_out_calls = outbound_filtered_calls_df.resample('W').size()

plt.figure(figsize=(14, 5))
plt.plot(weekly_success_deals, label='Deals')
plt.plot(weekly_out_calls, label='Outgoing calls')
plt.title('Deals and Outgoing calls by weeks')
plt.xlabel('Date')
plt.ylabel('Quantity')
plt.legend()
plt.show()

# %%
# Combine data by date
correlation_df = pd.DataFrame({
    'calls': weekly_out_calls,
    'deals': weekly_success_deals
}).dropna()

# Calculate the Pearson correlation coefficient
correlation = correlation_df['calls'].corr(correlation_df['deals'], method='pearson')

print(f"Pearson correlation coefficient between Outgoing calls (>3 sec) and deals: {correlation:.3f}")
# Out:
# Pearson correlation coefficient between Outgoing calls (>3 sec) and deals: 0.506

# %%
# Normalization of rows (MinMax Scaling)
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaled = scaler.fit_transform(pd.DataFrame({
    'calls': weekly_out_calls,
    'deals': weekly_success_deals
}).fillna(0))

scaled_df = pd.DataFrame(scaled, index=weekly_out_calls.index, columns=['calls', 'deals'])

plt.figure(figsize=(14, 5))
plt.plot(scaled_df['calls'], label='Calls (norm.)')
plt.plot(scaled_df['deals'], label='Deals (norm.)')
plt.title("Normalized time series of calls and deals")
plt.xlabel('Date')
plt.ylabel('Quantity')
plt.legend()
plt.show()

# %%
# Filter only lost trades
lost_df = deals_df[deals_df['Stage'] == 'Lost']

# %%
# check the dependence of lost deals and outgoing calls
weekly_lost_deals = lost_df.resample("W").count()['Id']  # Series

plt.figure(figsize=(14, 5))
plt.plot(weekly_lost_deals, label='Deals')
plt.plot(weekly_out_calls, label='Calls')
plt.title("Lost deals and Outgoing calls by weeks")
plt.xlabel('Date')
plt.ylabel('Quantity')
plt.legend()
plt.show()

# %%
# Combine data by date
correlation_df = pd.DataFrame({
    'calls': weekly_out_calls,
    'deals': weekly_lost_deals
}).dropna()

# Calculate the Pearson correlation coefficien
correlation = correlation_df['calls'].corr(correlation_df['deals'], method='pearson')

print(f"Pearson correlation coefficient between Outgoing calls (>3 sec) and lost deals: {correlation:.3f}")
# Out:
# Pearson correlation coefficient between Outgoing calls (>3 sec) and lost deals: 0.716

# %%
plt.figure(figsize=(14, 5))
plt.plot(weekly_lost_deals, label='Deals')
plt.plot(weekly_in_calls, label='Calls')
plt.title("Lost deals and Incoming calls by weeks")
plt.xlabel('Date')
plt.ylabel('Quantity')
plt.legend()
plt.show()

# %%
# Combine data by date
correlation_df = pd.DataFrame({
    'calls': weekly_in_calls,
    'deals': weekly_lost_deals
}).dropna()

# Calculate the Pearson correlation coefficien
correlation = correlation_df['calls'].corr(correlation_df['deals'], method='pearson')

print(f"Pearson correlation coefficient between Incoming calls (>3 sec) and lost deals: {correlation:.3f}")
# Out:
# Pearson correlation coefficient between Incoming calls (>3 sec) and lost deals: 0.601

# %%
# Filtering by all Stages, because at the stage of data cleaning for Stage='Payment Done' & 'Lost' the data for Closing date was filled
open_deals_df = deals_df[deals_df['Closing Date'].isna()]

# %%
#Let's look at the relationship between open deals and calls
weekly_process_deals = open_deals_df.resample("W").count()['Id']  # Series

plt.figure(figsize=(14, 5))
plt.plot(weekly_process_deals, label='Deals')
plt.plot(weekly_out_calls, label='Calls')
plt.title("Open deals and Outgoing calls by weeks")
plt.xlabel('Date')
plt.ylabel('Quantity')
plt.legend()
plt.show()

# %%
# Combine data by date
correlation_df = pd.DataFrame({
    'calls': weekly_out_calls,
    'deals': weekly_process_deals
}).dropna()

#  Calculate the Pearson correlation coefficien
correlation = correlation_df['calls'].corr(correlation_df['deals'], method='pearson')

print(f"Pearson correlation coefficient between Outgoing calls (>3 sec) and open deals: {correlation:.3f}")
# Out:
# Pearson correlation coefficient between Outgoing calls (>3 sec) and open deals: 0.595

# %%
plt.figure(figsize=(14, 5))
plt.plot(weekly_process_deals, label='Deals')
plt.plot(weekly_in_calls, label='Calls')
plt.title("Open deals and Incoming calls by weeks")
plt.xlabel('Date')
plt.ylabel('Quantity')
plt.legend()
plt.show()

# %%
# Combine data by date
correlation_df = pd.DataFrame({
    'calls': weekly_in_calls,
    'deals': weekly_process_deals
}).dropna()

#  Calculate the Pearson correlation coefficien
correlation = correlation_df['calls'].corr(correlation_df['deals'], method='pearson')

print(f"Pearson correlation coefficient between Incoming calls (>3 sec) and open deals: {correlation:.3f}")
# Out:
# Pearson correlation coefficient between Incoming calls (>3 sec) and open deals: 0.444

# %%
# If correlation > 0.5 — we can say that the connection is noticeable.

# If 0.2 < correlation < 0.5 — weak, but may be important under other conditions.

# If < 0.2 — most likely, calls and deals are not strongly directly related (including in time).

# %% [markdown]
# ## 2. Изучите распределение времени закрытия сделок и продолжительность периода от создания до закрытия.

# %%
deals_df_2 = pd.read_pickle("deals_cleaned_v3.pkl")
deals_df_2.head()
# Out:
#                     Id Deal Owner Name Closing Date            Quality  \
# 0  5805028000056864695        Ben Hall          NaT         B - Medium
# 1  5805028000056859489   Ulysses Adams          NaT         B - Medium
# 2  5805028000056832357   Ulysses Adams   2024-06-21     D - Non Target
# 3  5805028000056824246        Eva Kent   2024-06-21  E - Non Qualified
# 4  5805028000056873292        Ben Hall   2024-06-21     D - Non Target
#
#       Stage     Lost Reason       Page                  Campaign  \
# 0  New Lead             NaN  /eng/test             03.07.23women
# 1  New Lead             NaN    /at-eng                       NaN
# 2      Lost      Non target    /at-eng                engwien_at
# 3      Lost  Invalid number       /eng  04.07.23recentlymoved_de
# 4      Lost      Non target       /eng              discovery_de
#
#               SLA             Content  ... Course duration Months of study  \
# 0             NaT                 v16  ...             NaN            <NA>
# 1             NaT                 NaN  ...               6            <NA>
# 2 0 days 00:26:43               b1-at  ...             NaN            <NA>
# 3 0 days 01:00:04  bloggersvideo14com  ...             NaN            <NA>
# 4 0 days 00:53:12             website  ...             NaN            <NA>
#
#   Initial Amount Paid Offer Total Amount         Contact Name City  \
# 0                 NaN                NaN  5805028000056849495  NaN
# 1                 NaN             2000.0  5805028000056834471  NaN
# 2                 NaN                NaN  5805028000056854421  NaN
# 3                 NaN                NaN  5805028000056889351  NaN
# 4                 NaN                NaN  5805028000056876176  NaN
#
#   Level of Deutsch  Created Date  Create_to_Close_Days            SLA_range
# 0              NaN    2024-06-21                   NaN                  NaN
# 1              NaN    2024-06-21                   NaN                  NaN
# 2              NaN    2024-06-21                   0.0   Medium (15-30 min)
# 3              NaN    2024-06-21                   0.0  Very slow (>60 min)
# 4              NaN    2024-06-21                   0.0     Slow (30-60 min)
#
# [5 rows x 26 columns]

# %%
# Remove rows with empty Closing Date for correct timseries
close_all_deals_df = deals_df_2[deals_df_2['Closing Date'].notna()].copy()

# Set Closing Date as index
close_all_deals_df.set_index('Closing Date', inplace=True)

# %%
# Aggregate: count the number of all deals each day
daily_close_deals = close_all_deals_df.resample("D").size()  # time series by days

# Decomposition of the time series (period - 7, if we think that there is weekly seasonality)
decomposition = seasonal_decompose(daily_close_deals, model='additive', period=30)

# Extracting the components
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(12, 8))
plt.subplot(411)
plt.plot(daily_close_deals, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal, label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
daily_close_deals.tail(10)
# Out:
# Closing Date
# 2024-12-02    0
# 2024-12-03    0
# 2024-12-04    0
# 2024-12-05    0
# 2024-12-06    0
# 2024-12-07    0
# 2024-12-08    0
# 2024-12-09    0
# 2024-12-10    0
# 2024-12-11    1
# Freq: D, dtype: int64

# %%
deals_df_2[deals_df_2['Closing Date'] == '2024-12-11']
# Out:
#                         Id Deal Owner Name Closing Date         Quality Stage  \
# 12668  5805028000025477353      Nina Scott   2024-12-11  D - Non Target  Lost
#
#       Lost Reason       Page         Campaign             SLA Content  ...  \
# 12668  Non target  /eng/test  bloggershina_de 0 days 00:18:19     NaN  ...
#
#       Course duration Months of study Initial Amount Paid Offer Total Amount  \
# 12668             NaN            <NA>                 NaN                NaN
#
#               Contact Name City Level of Deutsch  Created Date  \
# 12668  5805028000016832230  NaN              NaN    2024-01-11
#
#        Create_to_Close_Days           SLA_range
# 12668                 335.0  Medium (15-30 min)
#
# [1 rows x 26 columns]

# %%
successfull_close_df = close_all_deals_df[close_all_deals_df['Stage'] == 'Payment Done']

# %%
# Aggregate: count the number of successful deals each day
daily_close_success_deals = successfull_close_df.resample("D").size()  # time series by days
# Decomposition of the time series (period - 7, if we think that there is weekly seasonality)
decomposition = seasonal_decompose(daily_close_success_deals, model='additive', period=30)

# Extracting the components
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(12, 8))
plt.subplot(411)
plt.plot(daily_close_success_deals, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal, label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
success_with_common_index = deals_df_2[deals_df_2['Stage'] == 'Payment Done']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
sns.histplot(deals_df_2['Create_to_Close_Days'].dropna(), bins=30, kde=True)
plt.title("Distribution of closing times for all deals")
plt.xlabel("Days from creation to closure")
plt.ylabel("Number of deals")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
sns.histplot(success_with_common_index['Create_to_Close_Days'].dropna(), bins=30, kde=True)
plt.title("Distribution of closing times of successful deals")
plt.xlabel("Days from creation to closure")
plt.ylabel("Number of deals")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 2))
sns.boxplot(x=deals_df_2['Create_to_Close_Days'].dropna(),medianprops=dict(color='red'))
plt.title('Boxplot of deals duration')
plt.xlabel("Days from creation to closing")
plt.grid(True)
plt.show()

# %%
# Let's take the logarithm of the scale for clarity
import numpy as np
deals_df_2['Create_to_Close_Days_log'] = np.log1p(deals_df_2['Create_to_Close_Days'])

sns.boxplot(x=deals_df_2['Create_to_Close_Days_log'].dropna(), medianprops=dict(color='red'))
plt.title("Boxplot of deals duration")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 4))
sns.boxplot(x=success_with_common_index['Create_to_Close_Days'].dropna(),medianprops=dict(color='red'))
plt.title('Boxplot of successfull deals duration')
plt.xlabel("Days from creation to closing")
plt.grid(True)
plt.show()

# %%
# df_tmp = successfull.reset_index(drop=True) # сбросить индекс и удалить старый (дату) из столбцов
plt.figure(figsize=(12, 5))
sns.boxplot(x='Product', y='Create_to_Close_Days', data=success_with_common_index.dropna(subset=['Create_to_Close_Days']),medianprops=dict(color='red'))
plt.title("Время закрытия по продуктам")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.scatter(success_with_common_index['Closing Date'], success_with_common_index['Create_to_Close_Days'], alpha=0.5)
plt.title("Time of closing successful trades in time")
plt.xlabel("Closing date")
plt.ylabel("Days")
plt.grid(True)
plt.show()

# %%
pivot = success_with_common_index.pivot_table(
    index='Deal Owner Name',
    columns='Product',
    values='Create_to_Close_Days',
    aggfunc='median', observed=False
) .fillna(0) # Replace NaNs with 0

plt.figure(figsize=(12, 6))
sns.heatmap(pivot, annot=True, fmt=".1f", cmap="YlGnBu")
plt.title("Median deal closing time by manager and product")
plt.show()
