# %%
import pandas as pd

# Загрузка Excel-файла с явным указанием типа данных
dtype_dict = {
    'Id': 'str',
    'CONTACTID': 'str',
}

calls_test = pd.read_excel('Calls (Done).xlsx', dtype=dtype_dict)

# Теперь calls_df — это твой DataFrame, с которым можно работать дальше

# %%
calls_test
# Out:
#                         Id   Call Start Time Call Owner Name  \
# 0      5805028000000805001  30.06.2023 08:43        John Doe
# 1      5805028000000768006  30.06.2023 08:46        John Doe
# 2      5805028000000764027  30.06.2023 08:59        John Doe
# 3      5805028000000787003  30.06.2023 09:20        John Doe
# 4      5805028000000768019  30.06.2023 09:30        John Doe
# ...                    ...               ...             ...
# 95869  5805028000056889515  21.06.2024 15:30   Ulysses Adams
# 95870  5805028000056875317  21.06.2024 15:30   Victor Barnes
# 95871  5805028000056832495  21.06.2024 15:30    Kevin Parker
# 95872  5805028000056893619  21.06.2024 15:30   Victor Barnes
# 95873  5805028000056893631  21.06.2024 15:31        John Doe
#
#                  CONTACTID Call Type  Call Duration (in seconds)  \
# 0                      NaN   Inbound                       171.0
# 1                      NaN  Outbound                        28.0
# ...

# %%
calls_test[calls_test.duplicated(subset='Id', keep=False)]
# Out:
# Empty DataFrame
# Columns: [Id, Call Start Time, Call Owner Name, CONTACTID, Call Type, Call Duration (in seconds), Call Status, Dialled Number, Outgoing Call Status, Scheduled in CRM, Tag]
# Index: []

# %%
print(calls_test.dtypes)
# Out:
# Id                             object
# Call Start Time                object
# Call Owner Name                object
# CONTACTID                      object
# Call Type                      object
# Call Duration (in seconds)    float64
# Call Status                    object
# Dialled Number                float64
# Outgoing Call Status           object
# Scheduled in CRM              float64
# Tag                           float64
# dtype: object

# %%
import pandas as pd

# Загрузка Excel-файла с явным указанием типа данных
dtype_dict = {
    'Id': 'str',
    'Contact Name': 'str'
}

deals_test = pd.read_excel('Deals (Done).xlsx', dtype=dtype_dict)

# %%
deals_test
# Out:
#                         Id Deal Owner Name Closing Date            Quality  \
# 0      5805028000056864695        Ben Hall          NaN                NaN
# 1      5805028000056859489   Ulysses Adams          NaN                NaN
# 2      5805028000056832357   Ulysses Adams   21.06.2024     D - Non Target
# 3      5805028000056824246        Eva Kent   21.06.2024  E - Non Qualified
# 4      5805028000056873292        Ben Hall   21.06.2024     D - Non Target
# ...                    ...             ...          ...                ...
# 21590  5805028000000945016      Jane Smith   29.08.2023           A - High
# 21591  5805028000000927004       Bob Brown   09.07.2023     D - Non Target
# 21592  5805028000000922001       Bob Brown   03.07.2023  E - Non Qualified
# 21593                  NaN             NaN          NaN                NaN
# 21594                  NaN             NaN          NaN                NaN
#
#           Stage             Lost Reason                   Page  \
# ...

# %%
deals_test[deals_test.duplicated(subset='Id', keep=False)]
# Out:
#         Id Deal Owner Name Closing Date Quality Stage Lost Reason Page  \
# 21593  NaN             NaN          NaN     NaN   NaN         NaN  NaN
# 21594  NaN             NaN          NaN     NaN   NaN         NaN  NaN
#
#       Campaign  SLA Content  ... Product Education Type Created Time  \
# 21593      NaN  NaN     NaN  ...     NaN            NaN          NaN
# 21594      NaN  NaN     NaN  ...     NaN          #REF!          NaN
#
#       Course duration Months of study Initial Amount Paid  Offer Total Amount  \
# 21593             NaN             NaN                 NaN                 NaN
# 21594             NaN             NaN                 NaN                 NaN
#
#        Contact Name City Level of Deutsch
# 21593           NaN  NaN              NaN
# 21594           NaN  NaN              NaN
#
# [2 rows x 23 columns]

# %%
print(deals_test.dtypes)
# Out:
# Id                      object
# Deal Owner Name         object
# Closing Date            object
# Quality                 object
# Stage                   object
# Lost Reason             object
# Page                    object
# Campaign                object
# SLA                     object
# Content                 object
# Term                    object
# Source                  object
# Payment Type            object
# Product                 object
# Education Type          object
# Created Time            object
# Course duration        float64
# Months of study        float64
# Initial Amount Paid     object
# Offer Total Amount      object
# Contact Name            object
# City                    object
# Level of Deutsch        object
# dtype: object

# %%
import pandas as pd

# Загрузка Excel-файла с явным указанием типа данных
dtype_dict = {
    'Id': 'str'
}

contacts_test = pd.read_excel('Contacts (Done).xlsx', dtype=dtype_dict)

# %%
contacts_test
# Out:
#                         Id Contact Owner Name      Created Time  \
# 0      5805028000000645014       Rachel White  27.06.2023 11:28
# 1      5805028000000872003      Charlie Davis  03.07.2023 11:31
# 2      5805028000000889001          Bob Brown  02.07.2023 22:37
# 3      5805028000000907006          Bob Brown  03.07.2023 05:44
# 4      5805028000000939010         Nina Scott  04.07.2023 10:11
# ...                    ...                ...               ...
# 18543  5805028000056889209      Ulysses Adams  21.06.2024 12:11
# 18544  5805028000056889351           Eva Kent  21.06.2024 13:32
# 18545  5805028000056892018           Eva Kent  21.06.2024 10:21
# 18546  5805028000056892055       Yara Edwards  21.06.2024 10:22
# 18547  5805028000056907001           Ben Hall  21.06.2024 10:56
#
#           Modified Time
# 0      22.12.2023 13:34
# 1      21.05.2024 10:23
# 2      21.12.2023 13:17
# 3      29.12.2023 15:20
# 4      16.04.2024 16:14
# ...                 ...
# ...

# %%
contacts_test[contacts_test.duplicated(subset='Id', keep=False)]
# Out:
# Empty DataFrame
# Columns: [Id, Contact Owner Name, Created Time, Modified Time]
# Index: []

# %%
print(contacts_test.dtypes)
# Out:
# Id                    object
# Contact Owner Name    object
# Created Time          object
# Modified Time         object
# dtype: object

# %%
import pandas as pd

# Загрузка Excel-файла с явным указанием типа данных
dtype_dict = {
    'Id': 'str'
}

spend_test = pd.read_excel('Spend (Done).xlsx', dtype=dtype_dict)

# %%
spend_test
# Out:
#             Date        Source                  Campaign  Impressions  Spend  \
# 0     2023-07-03    Google Ads            gen_analyst_DE            6   0.00
# 1     2023-07-03    Google Ads     performancemax_eng_DE            4   0.01
# 2     2023-07-03  Facebook Ads                       NaN            0   0.00
# 3     2023-07-03    Google Ads                       NaN            0   0.00
# 4     2023-07-03           CRM                       NaN            0   0.00
# ...          ...           ...                       ...          ...    ...
# 20774 2024-06-21  Facebook Ads           17.03.24wide_AT            7   0.07
# 20775 2024-06-21    Tiktok Ads         12.07.2023wide_DE           61   0.16
# 20776 2024-06-21   Partnership                       NaN            0   0.00
# 20777 2024-06-21    Tiktok Ads                       NaN            0   0.00
# 20778 2024-06-21  Facebook Ads  04.07.23recentlymoved_DE            7   0.05
#
# ...

# %%
print(spend_test.dtypes)
# Out:
# Date           datetime64[ns]
# Source                 object
# Campaign               object
# Impressions             int64
# Spend                 float64
# Clicks                  int64
# AdGroup                object
# Ad                     object
# dtype: object
