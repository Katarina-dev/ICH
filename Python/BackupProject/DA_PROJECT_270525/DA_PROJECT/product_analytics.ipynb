# %% [markdown]
# # Задание по продуктовой аналитике

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
deals_df = pd.read_pickle("deals_cleaned.pkl")
deals_df
# Out:
#                         Id  Deal Owner Name Closing Date            Quality  \
# 0      5805028000056864695         Ben Hall          NaT                NaN
# 1      5805028000056859489    Ulysses Adams          NaT                NaN
# 2      5805028000056832357    Ulysses Adams   2024-06-21     D - Non Target
# 3      5805028000056824246         Eva Kent   2024-06-21  E - Non Qualified
# 4      5805028000056873292         Ben Hall   2024-06-21     D - Non Target
# ...                    ...              ...          ...                ...
# 21406  5805028000050001603   Quincy Vincent   2024-05-15  E - Non Qualified
# 21407  5805028000053787195  Paula Underwood   2024-06-06  E - Non Qualified
# 21408  5805028000054823001   Quincy Vincent   2024-06-12  E - Non Qualified
# 21409  5805028000056685164    Charlie Davis   2024-06-20  E - Non Qualified
# 21410  5805028000056705395    Ulysses Adams   2024-06-20  E - Non Qualified
#
#           Stage     Lost Reason                  Campaign             SLA  \
# 0      New Lead             NaN             03.07.23women             NaT
# 1      New Lead             NaN                       NaN             NaT
# 2          Lost      Non target                engwien_at 0 days 00:26:43
# 3          Lost  Invalid number  04.07.23recentlymoved_de 0 days 01:00:04
# 4          Lost      Non target              discovery_de 0 days 00:53:12
# ...         ...             ...                       ...             ...
# 21406      Lost       Duplicate                       NaN 0 days 05:35:41
# 21407      Lost       Duplicate                       NaN             NaT
# 21408      Lost       Duplicate       brand_search_eng_de 0 days 04:30:17
# 21409      Lost       Duplicate                       NaN 0 days 00:01:46
# 21410      Lost       Duplicate                       NaN             NaT
#
#                Source Payment Type        Product Education Type  \
# 0        facebook ads          NaN            NaN            NaN
# 1             organic          NaN  Web Developer        Morning
# 2      telegram posts          NaN            NaN            NaN
# 3        facebook ads          NaN            NaN            NaN
# 4          google ads          NaN            NaN            NaN
# ...               ...          ...            ...            ...
# 21406         organic          NaN            NaN            NaN
# 21407         organic          NaN            NaN            NaN
# 21408      google ads          NaN            NaN            NaN
# 21409         organic          NaN            NaN            NaN
# 21410         organic          NaN            NaN            NaN
#
#              Created Time  Course duration  Months of study  \
# 0     2024-06-21 15:30:00             <NA>             <NA>
# 1     2024-06-21 15:23:00                6             <NA>
# 2     2024-06-21 14:45:00             <NA>             <NA>
# 3     2024-06-21 13:32:00             <NA>             <NA>
# 4     2024-06-21 13:21:00             <NA>             <NA>
# ...                   ...              ...              ...
# 21406 2024-05-15 08:50:00             <NA>             <NA>
# 21407 2024-06-06 18:45:00             <NA>             <NA>
# 21408 2024-06-12 05:46:00             <NA>             <NA>
# 21409 2024-06-20 13:49:00             <NA>             <NA>
# 21410 2024-06-20 17:36:00             <NA>             <NA>
#
#        Initial Amount Paid  Offer Total Amount         Contact Name City  \
# 0                      NaN                 NaN  5805028000056849495  NaN
# 1                      NaN            2,000.00  5805028000056834471  NaN
# 2                      NaN                 NaN  5805028000056854421  NaN
# 3                      NaN                 NaN  5805028000056889351  NaN
# 4                      NaN                 NaN  5805028000056876176  NaN
# ...                    ...                 ...                  ...  ...
# 21406                  NaN                 NaN  5805028000049855125  NaN
# 21407                  NaN                 NaN  5805028000053705642  NaN
# 21408                  NaN                 NaN  5805028000054480760  NaN
# 21409                  NaN                 NaN  5805028000056392363  NaN
# 21410                  NaN                 NaN  5805028000056727001  NaN
#
#       German level  Create_to_Close_Days  Latitude  Longitude  \
# 0              NaN                   NaN       NaN        NaN
# 1              NaN                   NaN       NaN        NaN
# 2              NaN                  0.00       NaN        NaN
# 3              NaN                  0.00       NaN        NaN
# 4              NaN                  0.00       NaN        NaN
# ...            ...                   ...       ...        ...
# 21406          NaN                  0.00       NaN        NaN
# 21407          NaN                  0.00       NaN        NaN
# 21408          NaN                  0.00       NaN        NaN
# 21409          NaN                  0.00       NaN        NaN
# 21410          NaN                  0.00       NaN        NaN
#
#                  SLA_range
# 0                      NaN
# 1                      NaN
# 2       Medium (15-30 min)
# 3      Very slow (>60 min)
# 4         Slow (30-60 min)
# ...                    ...
# 21406  Very slow (>60 min)
# 21407                  NaN
# 21408  Very slow (>60 min)
# 21409   Very fast (≤5 min)
# 21410                  NaN
#
# [21411 rows x 24 columns]

# %%
deals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21411 entries, 0 to 21410
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    21411 non-null  object
#  1   Deal Owner Name       21382 non-null  object
#  2   Closing Date          16685 non-null  datetime64[ns]
#  3   Quality               19158 non-null  category
#  4   Stage                 21411 non-null  category
#  5   Lost Reason           15942 non-null  category
#  6   Campaign              16006 non-null  object
#  7   SLA                   15504 non-null  timedelta64[ns]
#  8   Source                21411 non-null  object
#  9   Payment Type          496 non-null    category
#  10  Product               3592 non-null   category
#  11  Education Type        3299 non-null   category
#  12  Created Time          21411 non-null  datetime64[ns]
#  13  Course duration       3587 non-null   Int64
#  14  Months of study       840 non-null    Int64
#  15  Initial Amount Paid   3289 non-null   float64
#  16  Offer Total Amount    3337 non-null   float64
#  17  Contact Name          21350 non-null  object
#  18  City                  2831 non-null   object
#  19  German level          1584 non-null   category
#  20  Create_to_Close_Days  16685 non-null  float64
#  21  Latitude              2824 non-null   float64
#  22  Longitude             2824 non-null   float64
#  23  SLA_range             15504 non-null  category
# dtypes: Int64(2), category(8), datetime64[ns](2), float64(5), object(6), timedelta64[ns](1)
# memory usage: 2.8+ MB

# %% [raw]
# Для расчета среднего чека по каждой сделке добавим колонку AOV_i и рассчитаем по формуле:

# %% [markdown]
# $$
# AOV_i = \frac{\text{Initial Amount Paid} + \left(\text{Offer Total Amount} - \text{Initial Amount Paid}\right)}{\text{Course duration} - 1} \cdot (\text{Months of study} - 1) \div \text{Months of study}
# $$

# %% [raw]
# Убедимся, что в Course duration нет значений равных 1 (иначе получим деление на 0)

# %% [raw]
# Изменим тип данных для Course duration с категориального на числовой. Т.к. в поле есть пропуски, сделаем обработку таких ошибок и замним пропуски на 0:

# %%
deals_df['Course duration'] = pd.to_numeric(deals_df['Course duration'], errors='coerce')
deals_df['Course duration'] = deals_df['Course duration'].fillna(0).astype(int)

# %% [raw]
# Добавляем колонку AOV_i

# %%
import numpy as np

# Условия для валидных строк
valid = (
    deals_df['Initial Amount Paid'].notna() &
    deals_df['Offer Total Amount'].notna() &
    deals_df['Course duration'].notna() &
    deals_df['Months of study'].notna() &
    (deals_df['Course duration'] != 1) &
    (deals_df['Months of study'] != 0)
)

# Расчёт AOV_i с приведением к float64
deals_df['AOV_i'] = np.where(
    valid,
    (
        deals_df['Initial Amount Paid'] +
        ((deals_df['Offer Total Amount'] - deals_df['Initial Amount Paid']) /
         (deals_df['Course duration'] - 1)) *
        (deals_df['Months of study'] - 1)
    ) / deals_df['Months of study'],
    np.nan
).astype('float64') #Т.к. тип данных получается Float64 (с большой буквы), то это может испортить данные (возвращает pd.NA вместо pd.nan и ломает вычисления даже при отсутствии строк с NaN), поэтому меняем тип на float64:

# %%
deals_df[deals_df['AOV_i'].notna()]
# Out:
#                         Id Deal Owner Name Closing Date         Quality  \
# 463    5805028000055502703        Eva Kent   2024-06-18      B - Medium
# 473    5805028000055524315        Ben Hall   2024-06-19        A - High
# 491    5805028000055524040        Ben Hall   2024-06-23      B - Medium
# 824    5805028000054664018        Ben Hall   2024-06-19  D - Non Target
# 1029   5805028000054257317  Quincy Vincent   2024-06-17      B - Medium
# ...                    ...             ...          ...             ...
# 21034  5805028000002302112    Julia Nelson   2023-07-19         C - Low
# 21087  5805028000001987082    Julia Nelson   2023-07-17         C - Low
# 21130  5805028000001885076      Jane Smith   2023-08-31        A - High
# 21265  5805028000001401001   Oliver Taylor   2023-07-16      B - Medium
# 21296  5805028000000947046   Oliver Taylor   2023-07-12      B - Medium
#
#               Stage                  Lost Reason  \
# 463    Payment Done                          NaN
# 473    Payment Done                          NaN
# 491    Payment Done                          NaN
# 824    Payment Done                          NaN
# 1029   Payment Done                          NaN
# ...             ...                          ...
# 21034  Payment Done                    Expensive
# 21087  Payment Done  Conditions are not suitable
# 21130  Payment Done                          NaN
# 21265  Payment Done                          NaN
# 21296  Payment Done                          NaN
#
#                                 Campaign              SLA          Source  \
# 463               performancemax_wide_at  0 days 14:35:20      google ads
# 473                    12.07.2023wide_de  0 days 00:17:25      tiktok ads
# 491                              live_de  0 days 00:23:42  telegram posts
# 824                                  NaN  0 days 16:31:52         organic
# 1029                     02.07.23wide_de  0 days 00:45:55    facebook ads
# ...                                  ...              ...             ...
# 21034  performancemax_digitalmarkt_ru_de  0 days 15:24:52      google ads
# 21087                  12.07.2023wide_de  0 days 00:49:16      tiktok ads
# 21130           04.07.23recentlymoved_de  0 days 00:13:31    facebook ads
# 21265                    02.07.23wide_de  0 days 02:22:36    facebook ads
# 21296                    02.07.23wide_de 71 days 00:46:22    facebook ads
#
#              Payment Type            Product Education Type  \
# 463    Recurring Payments  Digital Marketing        Evening
# 473    Recurring Payments  Digital Marketing        Evening
# 491                   NaN      Web Developer        Morning
# 824                   NaN      Web Developer        Morning
# 1029                  NaN  Digital Marketing        Morning
# ...                   ...                ...            ...
# 21034                 NaN      Web Developer        Morning
# 21087                 NaN  Digital Marketing        Morning
# 21130         One Payment  Digital Marketing        Morning
# 21265                 NaN  Digital Marketing            NaN
# 21296                 NaN  Digital Marketing        Morning
#
#              Created Time  Course duration  Months of study  \
# 463   2024-06-15 20:01:00               11                1
# 473   2024-06-15 17:02:00               11                1
# 491   2024-06-15 12:20:00                6                1
# 824   2024-06-11 19:39:00                6                1
# 1029  2024-06-10 15:33:00               11                1
# ...                   ...              ...              ...
# 21034 2023-07-18 21:11:00                6                2
# 21087 2023-07-17 18:02:00               11               11
# 21130 2023-07-15 13:27:00               11               11
# 21265 2023-07-08 08:56:00               11                8
# 21296 2023-07-04 10:11:00               11               11
#
#        Initial Amount Paid  Offer Total Amount         Contact Name  \
# 463                 500.00            4,500.00  5805028000055471387
# 473                 500.00            4,500.00  5805028000055503302
# 491               1,000.00            9,000.00  5805028000055464156
# 824               1,000.00            9,000.00  5805028000054683001
# 1029              1,000.00           11,000.00  5805028000054284461
# ...                    ...                 ...                  ...
# 21034             1,000.00            5,000.00  5805028000002302109
# 21087             1,000.00           11,000.00  5805028000001986077
# 21130               450.00            4,000.00  5805028000001880249
# 21265             1,000.00           11,500.00  5805028000001350049
# 21296             1,000.00           11,000.00  5805028000000939010
#
#                           City German level  Create_to_Close_Days  Latitude  \
# 463                  Podskalie          NaN                  3.00     48.17
# 473                  Zinnowitz          NaN                  4.00     54.08
# 491                  Wolfsburg           B1                  8.00     52.42
# 824                    Zwickau           A2                  8.00     50.72
# 1029   Leinfelden-Echterdingen           B1                  7.00     48.69
# ...                        ...          ...                   ...       ...
# 21034                Wolfsburg           B1                  1.00     52.42
# 21087                      NaN           B1                  0.00       NaN
# 21130               Ingolstadt          NaN                 47.00     48.77
# 21265                      NaN          NaN                  8.00       NaN
# 21296                  Hamburg          NaN                  8.00     53.55
#
#        Longitude            SLA_range    AOV_i
# 463        18.32  Very slow (>60 min)   500.00
# 473        13.91   Medium (15-30 min)   500.00
# 491        10.79   Medium (15-30 min) 1,000.00
# 824        12.49  Very slow (>60 min) 1,000.00
# 1029        9.15     Slow (30-60 min) 1,000.00
# ...          ...                  ...      ...
# 21034      10.79  Very slow (>60 min)   900.00
# 21087        NaN     Slow (30-60 min) 1,000.00
# 21130      11.42      Fast (5-15 min)   363.64
# 21265        NaN  Very slow (>60 min) 1,043.75
# 21296       9.99  Very slow (>60 min) 1,000.00
#
# [838 rows x 25 columns]

# %% [raw]
# Добавим колонку с вычислением по формуле:

# %% [markdown]
# $$
# Revenue_i = AOV_i \times \text{Months of study}
# $$

# %%
deals_df['Revenue_i'] = (deals_df['AOV_i'] * deals_df['Months of study']).astype('float64') #Т.к. тип данных получается Float64 (с большой буквы), то это может испортить данные (возвращает pd.NA вместо pd.nan и ломает вычисления даже при отсутствии строк с NaN), поэтому меняем тип на float64:

# %%
deals_df[deals_df['AOV_i'].notna()]
# Out:
#                         Id Deal Owner Name Closing Date         Quality  \
# 463    5805028000055502703        Eva Kent   2024-06-18      B - Medium
# 473    5805028000055524315        Ben Hall   2024-06-19        A - High
# 491    5805028000055524040        Ben Hall   2024-06-23      B - Medium
# 824    5805028000054664018        Ben Hall   2024-06-19  D - Non Target
# 1029   5805028000054257317  Quincy Vincent   2024-06-17      B - Medium
# ...                    ...             ...          ...             ...
# 21034  5805028000002302112    Julia Nelson   2023-07-19         C - Low
# 21087  5805028000001987082    Julia Nelson   2023-07-17         C - Low
# 21130  5805028000001885076      Jane Smith   2023-08-31        A - High
# 21265  5805028000001401001   Oliver Taylor   2023-07-16      B - Medium
# 21296  5805028000000947046   Oliver Taylor   2023-07-12      B - Medium
#
#               Stage                  Lost Reason  \
# 463    Payment Done                          NaN
# 473    Payment Done                          NaN
# 491    Payment Done                          NaN
# 824    Payment Done                          NaN
# 1029   Payment Done                          NaN
# ...             ...                          ...
# 21034  Payment Done                    Expensive
# 21087  Payment Done  Conditions are not suitable
# 21130  Payment Done                          NaN
# 21265  Payment Done                          NaN
# 21296  Payment Done                          NaN
#
#                                 Campaign              SLA          Source  \
# 463               performancemax_wide_at  0 days 14:35:20      google ads
# 473                    12.07.2023wide_de  0 days 00:17:25      tiktok ads
# 491                              live_de  0 days 00:23:42  telegram posts
# 824                                  NaN  0 days 16:31:52         organic
# 1029                     02.07.23wide_de  0 days 00:45:55    facebook ads
# ...                                  ...              ...             ...
# 21034  performancemax_digitalmarkt_ru_de  0 days 15:24:52      google ads
# 21087                  12.07.2023wide_de  0 days 00:49:16      tiktok ads
# 21130           04.07.23recentlymoved_de  0 days 00:13:31    facebook ads
# 21265                    02.07.23wide_de  0 days 02:22:36    facebook ads
# 21296                    02.07.23wide_de 71 days 00:46:22    facebook ads
#
#              Payment Type            Product Education Type  \
# 463    Recurring Payments  Digital Marketing        Evening
# 473    Recurring Payments  Digital Marketing        Evening
# 491                   NaN      Web Developer        Morning
# 824                   NaN      Web Developer        Morning
# 1029                  NaN  Digital Marketing        Morning
# ...                   ...                ...            ...
# 21034                 NaN      Web Developer        Morning
# 21087                 NaN  Digital Marketing        Morning
# 21130         One Payment  Digital Marketing        Morning
# 21265                 NaN  Digital Marketing            NaN
# 21296                 NaN  Digital Marketing        Morning
#
#              Created Time  Course duration  Months of study  \
# 463   2024-06-15 20:01:00               11                1
# 473   2024-06-15 17:02:00               11                1
# 491   2024-06-15 12:20:00                6                1
# 824   2024-06-11 19:39:00                6                1
# 1029  2024-06-10 15:33:00               11                1
# ...                   ...              ...              ...
# 21034 2023-07-18 21:11:00                6                2
# 21087 2023-07-17 18:02:00               11               11
# 21130 2023-07-15 13:27:00               11               11
# 21265 2023-07-08 08:56:00               11                8
# 21296 2023-07-04 10:11:00               11               11
#
#        Initial Amount Paid  Offer Total Amount         Contact Name  \
# 463                 500.00            4,500.00  5805028000055471387
# 473                 500.00            4,500.00  5805028000055503302
# 491               1,000.00            9,000.00  5805028000055464156
# 824               1,000.00            9,000.00  5805028000054683001
# 1029              1,000.00           11,000.00  5805028000054284461
# ...                    ...                 ...                  ...
# 21034             1,000.00            5,000.00  5805028000002302109
# 21087             1,000.00           11,000.00  5805028000001986077
# 21130               450.00            4,000.00  5805028000001880249
# 21265             1,000.00           11,500.00  5805028000001350049
# 21296             1,000.00           11,000.00  5805028000000939010
#
#                           City German level  Create_to_Close_Days  Latitude  \
# 463                  Podskalie          NaN                  3.00     48.17
# 473                  Zinnowitz          NaN                  4.00     54.08
# 491                  Wolfsburg           B1                  8.00     52.42
# 824                    Zwickau           A2                  8.00     50.72
# 1029   Leinfelden-Echterdingen           B1                  7.00     48.69
# ...                        ...          ...                   ...       ...
# 21034                Wolfsburg           B1                  1.00     52.42
# 21087                      NaN           B1                  0.00       NaN
# 21130               Ingolstadt          NaN                 47.00     48.77
# 21265                      NaN          NaN                  8.00       NaN
# 21296                  Hamburg          NaN                  8.00     53.55
#
#        Longitude            SLA_range    AOV_i  Revenue_i
# 463        18.32  Very slow (>60 min)   500.00     500.00
# 473        13.91   Medium (15-30 min)   500.00     500.00
# 491        10.79   Medium (15-30 min) 1,000.00   1,000.00
# 824        12.49  Very slow (>60 min) 1,000.00   1,000.00
# 1029        9.15     Slow (30-60 min) 1,000.00   1,000.00
# ...          ...                  ...      ...        ...
# 21034      10.79  Very slow (>60 min)   900.00   1,800.00
# 21087        NaN     Slow (30-60 min) 1,000.00  11,000.00
# 21130      11.42      Fast (5-15 min)   363.64   4,000.00
# 21265        NaN  Very slow (>60 min) 1,043.75   8,350.00
# 21296       9.99  Very slow (>60 min) 1,000.00  11,000.00
#
# [838 rows x 26 columns]

# %%
print(deals_df['Revenue_i'].dtype)
print(deals_df['AOV_i'].dtype)
# Out:
# float64
# float64

# %% [raw]
# Теперь можем вычислить средний чек по формуле:

# %% [markdown]
# $$
# AOV = \frac{\sum Revenue_i}{\sum \text{Months of study}}
# $$

# %%
aov = (
    deals_df['Revenue_i'].sum(skipna=True) /
    deals_df['Months of study'].sum(skipna=True)
)
print(f"AOV = {aov:.2f}")
# Out:
# AOV = 783.21

# %%
contacts_df = pd.read_pickle("contacts_cleaned.pkl")
contacts_df
# Out:
#                         Id Contact Owner Name        Created Time  \
# 0      5805028000000645014       Rachel White 2023-06-27 11:28:00
# 1      5805028000000872003      Charlie Davis 2023-07-03 11:31:00
# 2      5805028000000889001          Bob Brown 2023-07-02 22:37:00
# 3      5805028000000907006          Bob Brown 2023-07-03 05:44:00
# 4      5805028000000939010         Nina Scott 2023-07-04 10:11:00
# ...                    ...                ...                 ...
# 18543  5805028000056889209      Ulysses Adams 2024-06-21 12:11:00
# 18544  5805028000056889351           Eva Kent 2024-06-21 13:32:00
# 18545  5805028000056892018           Eva Kent 2024-06-21 10:21:00
# 18546  5805028000056892055       Yara Edwards 2024-06-21 10:22:00
# 18547  5805028000056907001           Ben Hall 2024-06-21 10:56:00
#
#             Modified Time
# 0     2023-12-22 13:34:00
# 1     2024-05-21 10:23:00
# 2     2023-12-21 13:17:00
# 3     2023-12-29 15:20:00
# 4     2024-04-16 16:14:00
# ...                   ...
# 18543 2024-06-21 14:11:00
# 18544 2024-06-21 15:32:00
# 18545 2024-06-21 12:21:00
# 18546 2024-06-21 12:23:00
# 18547 2024-06-21 12:56:00
#
# [18548 rows x 4 columns]

# %%
spend_df = pd.read_pickle("spend_cleaned.pkl")
spend_df
# Out:
#             Date        Source                  Campaign  Impressions  Spend  \
# 0     2023-07-03    google ads            gen_analyst_de            6   0.00
# 1     2023-07-03    google ads     performancemax_eng_de            4   0.01
# 2     2023-07-03  facebook ads             03.07.23women          187   3.30
# 3     2023-07-03  facebook ads             03.07.23women            4   0.02
# 4     2023-07-03  facebook ads           02.07.23wide_de           61   0.58
# ...          ...           ...                       ...          ...    ...
# 16395 2024-06-21    tiktok ads         22.05.2024wide_de            7   0.03
# 16396 2024-06-21   youtube ads         youtube_shorts_de           90   0.51
# 16397 2024-06-21  facebook ads           17.03.24wide_at            7   0.07
# 16398 2024-06-21    tiktok ads         12.07.2023wide_de           61   0.16
# 16399 2024-06-21  facebook ads  04.07.23recentlymoved_de            7   0.05
#
#        Clicks        AdGroup
# 0           0            NaN
# 1           1            NaN
# 2           6          women
# 3           1          women
# 4           0           wide
# ...       ...            ...
# 16395       0           wide
# 16396       2     com_august
# 16397       0           wide
# 16398       0           wide
# 16399       1  recentlymoved
#
# [16400 rows x 7 columns]

# %%
deals_df['Contact Name'].nunique()
# Out:
# 18089

# %%
deals_df[deals_df['Months of study'].isna()]
# Out:
#                         Id  Deal Owner Name Closing Date            Quality  \
# 0      5805028000056864695         Ben Hall          NaT                NaN
# 1      5805028000056859489    Ulysses Adams          NaT                NaN
# 2      5805028000056832357    Ulysses Adams   2024-06-21     D - Non Target
# 3      5805028000056824246         Eva Kent   2024-06-21  E - Non Qualified
# 4      5805028000056873292         Ben Hall   2024-06-21     D - Non Target
# ...                    ...              ...          ...                ...
# 21406  5805028000050001603   Quincy Vincent   2024-05-15  E - Non Qualified
# 21407  5805028000053787195  Paula Underwood   2024-06-06  E - Non Qualified
# 21408  5805028000054823001   Quincy Vincent   2024-06-12  E - Non Qualified
# 21409  5805028000056685164    Charlie Davis   2024-06-20  E - Non Qualified
# 21410  5805028000056705395    Ulysses Adams   2024-06-20  E - Non Qualified
#
#           Stage     Lost Reason                  Campaign             SLA  \
# 0      New Lead             NaN             03.07.23women             NaT
# 1      New Lead             NaN                       NaN             NaT
# 2          Lost      Non target                engwien_at 0 days 00:26:43
# 3          Lost  Invalid number  04.07.23recentlymoved_de 0 days 01:00:04
# 4          Lost      Non target              discovery_de 0 days 00:53:12
# ...         ...             ...                       ...             ...
# 21406      Lost       Duplicate                       NaN 0 days 05:35:41
# 21407      Lost       Duplicate                       NaN             NaT
# 21408      Lost       Duplicate       brand_search_eng_de 0 days 04:30:17
# 21409      Lost       Duplicate                       NaN 0 days 00:01:46
# 21410      Lost       Duplicate                       NaN             NaT
#
#                Source Payment Type        Product Education Type  \
# 0        facebook ads          NaN            NaN            NaN
# 1             organic          NaN  Web Developer        Morning
# 2      telegram posts          NaN            NaN            NaN
# 3        facebook ads          NaN            NaN            NaN
# 4          google ads          NaN            NaN            NaN
# ...               ...          ...            ...            ...
# 21406         organic          NaN            NaN            NaN
# 21407         organic          NaN            NaN            NaN
# 21408      google ads          NaN            NaN            NaN
# 21409         organic          NaN            NaN            NaN
# 21410         organic          NaN            NaN            NaN
#
#              Created Time  Course duration  Months of study  \
# 0     2024-06-21 15:30:00                0             <NA>
# 1     2024-06-21 15:23:00                6             <NA>
# 2     2024-06-21 14:45:00                0             <NA>
# 3     2024-06-21 13:32:00                0             <NA>
# 4     2024-06-21 13:21:00                0             <NA>
# ...                   ...              ...              ...
# 21406 2024-05-15 08:50:00                0             <NA>
# 21407 2024-06-06 18:45:00                0             <NA>
# 21408 2024-06-12 05:46:00                0             <NA>
# 21409 2024-06-20 13:49:00                0             <NA>
# 21410 2024-06-20 17:36:00                0             <NA>
#
#        Initial Amount Paid  Offer Total Amount         Contact Name City  \
# 0                      NaN                 NaN  5805028000056849495  NaN
# 1                      NaN            2,000.00  5805028000056834471  NaN
# 2                      NaN                 NaN  5805028000056854421  NaN
# 3                      NaN                 NaN  5805028000056889351  NaN
# 4                      NaN                 NaN  5805028000056876176  NaN
# ...                    ...                 ...                  ...  ...
# 21406                  NaN                 NaN  5805028000049855125  NaN
# 21407                  NaN                 NaN  5805028000053705642  NaN
# 21408                  NaN                 NaN  5805028000054480760  NaN
# 21409                  NaN                 NaN  5805028000056392363  NaN
# 21410                  NaN                 NaN  5805028000056727001  NaN
#
#       German level  Create_to_Close_Days  Latitude  Longitude  \
# 0              NaN                   NaN       NaN        NaN
# 1              NaN                   NaN       NaN        NaN
# 2              NaN                  0.00       NaN        NaN
# 3              NaN                  0.00       NaN        NaN
# 4              NaN                  0.00       NaN        NaN
# ...            ...                   ...       ...        ...
# 21406          NaN                  0.00       NaN        NaN
# 21407          NaN                  0.00       NaN        NaN
# 21408          NaN                  0.00       NaN        NaN
# 21409          NaN                  0.00       NaN        NaN
# 21410          NaN                  0.00       NaN        NaN
#
#                  SLA_range  AOV_i  Revenue_i
# 0                      NaN    NaN        NaN
# 1                      NaN    NaN        NaN
# 2       Medium (15-30 min)    NaN        NaN
# 3      Very slow (>60 min)    NaN        NaN
# 4         Slow (30-60 min)    NaN        NaN
# ...                    ...    ...        ...
# 21406  Very slow (>60 min)    NaN        NaN
# 21407                  NaN    NaN        NaN
# 21408  Very slow (>60 min)    NaN        NaN
# 21409   Very fast (≤5 min)    NaN        NaN
# 21410                  NaN    NaN        NaN
#
# [20571 rows x 26 columns]

# %% [markdown]
# ## Расчет общей юнит-экономики

# %% [raw]
# Рассчитаем метрики юнит-экономики:
#
# UA = contacts_df['Id'].nunique() -- поток юнитов масштабирования
#
# AC = spend_df['Spend'].sum() -- маректинговый бюджет
#
# LTC (CPA) = AC / UA -- стоимость привлечения юнита масштабирования
#
# B = deals_df[deals_df['Stage'] == 'Payment Done']['Contact Name'].count() -- количество клиентов
#
# C1 = B / UA -- конверсия из лида в клиента
#
# T = deals_df['Months of study'].sum() -- количество транзакций
#
# APC = T / B -- среднее число сделок на одного клиента
#
# CLTV = (AOV - COGS) * APC -- средняя валовая прибыль на клиента (COGS у нас нет)
#
# LTV = CLTV * С1 -- средняя валовая прибыль на юнит масштабирования
#
# CM = UA * (LTV - LTC) -- маржинальная прибыль в юнит-экономике
#
# Revenue = B * AOV * APC

# %%
# -- поток юнитов масштабирования --
ua = contacts_df['Id'].nunique() 

# -- маректинговый бюджет -- 
ac = spend_df['Spend'].sum()

# -- стоимость привлечения юнита масштабирования --
ltc_cpa = ac / ua

# -- количество клиентов -- 
b = deals_df[
    (deals_df['Stage'] == 'Payment Done') &
    (deals_df['Initial Amount Paid'].notna()) &
    (deals_df['Months of study'].notna())
]['Contact Name'].nunique()

# -- конверсия из лида в клиента -- 
c1 = b / ua

# -- количество транзакций --
t = deals_df[
    (deals_df['Stage'] == 'Payment Done') &
    (deals_df['Initial Amount Paid'].notna()) 
]['Months of study'].sum()

# -- среднее число сделок на одного клиента --
apc = t / b

# -- средняя валовая прибыль на клиента --
cltv = aov * apc

# -- средняя валовая прибыль на юнит масштабирования --
ltv = cltv * c1

# Стоимость привлечения клиента
cac = ac / b

# -- выручка --
revenue = b * aov * apc #deals_df['Revenue_i'].sum(skipna=True)

# -- маржинальная прибыль в юнит-экономике --
cm = ua * (ltv - ltc_cpa)

print(f'''AOV: {aov:.2f}
UA: {ua}
LTC (CPA): {ltc_cpa:.2f}
AC: {ac}
C1: {c1:.4f}
B: {b}
T: {t}
APC: {apc:.2f}
CLTV: {cltv:.2f}
LTV: {ltv:.2f}
CAC: {cac:.2f}
Revenue: {revenue:.2f}
CM: {cm:.2f}
''')
# Out:
# AOV: 783.21
# UA: 18548
# LTC (CPA): 8.06
# AC: 149523.45
# C1: 0.0446
# B: 827
# T: 4561
# APC: 5.52
# CLTV: 4319.47
# LTV: 192.59
# CAC: 180.80
# Revenue: 3572199.74
# CM: 3422676.29

# %%
# Соберём всё в датафрейм
metrics = {
    'Metric': [
        'AOV', 'UA', 'LTC (CPA)', 'AC', 'C1', 'B', 'T', 'APC',
        'CLTV', 'LTV', 'CAC', 'Revenue', 'CM'
    ],
    'Value': [
        round(aov, 2), ua, round(ltc_cpa, 2), round(ac, 2), round(c1, 4), b, t,
        round(apc, 2), round(cltv, 2), round(ltv, 2), round(cac, 2),
        round(revenue, 2), round(cm, 2)
    ]
}
metrics_df = pd.DataFrame(metrics)

metrics_df['Value'] = metrics_df['Value'].apply(
    lambda x: f"{x:,.2f}" if isinstance(x, float) else f"{x:,}"
)

# %%
metrics_df
# Out:
#        Metric         Value
# 0         AOV        783.21
# 1          UA     18,548.00
# 2   LTC (CPA)          8.06
# 3          AC    149,523.45
# 4          C1          0.04
# 5           B        827.00
# 6           T      4,561.00
# 7         APC          5.52
# 8        CLTV      4,319.47
# 9         LTV        192.59
# 10        CAC        180.80
# 11    Revenue  3,572,199.74
# 12         CM  3,422,676.29

# %%
metrics_df.to_pickle('metrics.pkl')

# %%
import pandas as pd

def calculate_unit_economics_by_product(deals_df, contacts_df, spend_df):
    # Общие метрики
    total_ua = contacts_df['Id'].nunique()
    total_ac = spend_df['Spend'].sum()
    total_ltc_cpa = total_ac / total_ua if total_ua != 0 else 0

    results = []

    # Только успешные сделки
    success_deals = deals_df[
        (deals_df['Stage'] == 'Payment Done') &
        (deals_df['Initial Amount Paid'].notna())&
        (deals_df['Months of study'].notna())
    ]

    # Группировка только по Product, исключаем пустые значения
    grouped = success_deals.dropna(subset=['Product']).groupby('Product', observed=True)

    for product, group in grouped:
        buyers = group['Contact Name'].nunique()
        c1 = buyers / total_ua if total_ua != 0 else 0
        total_months = group['Months of study'].sum()
        apc = total_months / buyers if buyers != 0 else 0
        aov = group['Revenue_i'].sum() / total_months if total_months != 0 else 0
        cltv = aov * apc
        ltv = cltv * c1
        cac = total_ac / buyers if buyers != 0 else 0
        revenue = buyers * aov * apc
        cm = total_ua * (ltv - total_ltc_cpa)

        results.append({
            'Product': product,
            'AOV': aov,
            'UA': total_ua,
            'LTC (CPA)': total_ltc_cpa,
            'AC': total_ac,
            'C1': c1,
            'B': buyers,
            'T': total_months,
            'APC': apc,
            'CLTV': cltv,
            'LTV': ltv,
            'CAC': cac,
            'Revenue': revenue,
            'CM': cm
        })

    return pd.DataFrame(results)

product_df = calculate_unit_economics_by_product(deals_df, contacts_df, spend_df)
product_df
# Out:
#              Product    AOV     UA  LTC (CPA)         AC   C1    B     T  APC  \
# 0  Digital Marketing 783.95  18548       8.06 149,523.45 0.03  468  2886 6.17
# 1       UX/UI Design 813.37  18548       8.06 149,523.45 0.01  226  1170 5.18
# 2      Web Developer 726.10  18548       8.06 149,523.45 0.01  135   505 3.74
#
#       CLTV    LTV      CAC      Revenue           CM
# 0 4,834.38 121.98   319.49 2,262,490.00 2,112,966.55
# 1 4,210.82  51.31   661.61   951,645.00   802,121.55
# 2 2,716.15  19.77 1,107.58   366,680.00   217,156.55

# %%
pd.set_option('display.float_format', '{:,.3f}'.format)

# %%
import pandas as pd

def calculate_unit_economics_by_group(deals_df, contacts_df, spend_df):
    # Общие метрики
    ua_prod = contacts_df['Id'].nunique()
    ac_prod = spend_df['Spend'].sum()
    ltc_cpa_prod = ac_prod / ua_prod if ua_prod != 0 else 0

    results = []

    success_deals = deals_df[
    (deals_df['Stage'] == 'Payment Done') &
    (deals_df['Initial Amount Paid'].notna())
]

    # Группировка по Product и Education Type, без NaN
    grouped = success_deals.dropna(subset=['Product', 'Education Type']) \
                      .groupby(['Product', 'Education Type'], observed=True)

    for (product, edu_type), df_group in grouped:
        b_prod = df_group[
            (df_group['Stage'] == 'Payment Done') &
            (df_group['Initial Amount Paid'].notna())
        ]['Contact Name'].nunique()

        c1_prod = b_prod / ua_prod if ua_prod != 0 else 0
        t_prod = df_group['Months of study'].sum()
        apc_prod = t_prod / b_prod if b_prod != 0 else 0
        aov_prod = df_group['Revenue_i'].sum() / t_prod if t_prod != 0 else 0
        cltv_prod = aov_prod * apc_prod
        ltv_prod = cltv_prod * c1_prod
        cac_prod = ac_prod / b_prod
        revenue_prod = b_prod * aov_prod * apc_prod
        cm_prod = ua_prod * (ltv_prod - ltc_cpa_prod)
       
        results.append({
            'Product': product,
            'Education Type': edu_type,
            'AOV': aov_prod,
            'UA': ua_prod,
            'LTC (CPA)': ltc_cpa_prod,
            'AC': ac_prod,
            'C1': c1_prod,
            'B': b_prod,
            'T': t_prod,
            'APC': apc_prod,
            'CLTV': cltv_prod,
            'LTV': ltv_prod,   
            'CAC': cac_prod,
            'Revenue': revenue_prod,
            'CM': cm_prod
        })

    unit_economics_by_group_df = pd.DataFrame(results)
    return unit_economics_by_group_df

unit_df = calculate_unit_economics_by_group(deals_df, contacts_df, spend_df)
pd.set_option('display.float_format', '{:,.2f}'.format)
unit_df
# Out:
#              Product Education Type    AOV     UA  LTC (CPA)         AC   C1  \
# 0  Digital Marketing        Evening 365.69  18548       8.06 149,523.45 0.01
# 1  Digital Marketing        Morning 931.25  18548       8.06 149,523.45 0.02
# 2       UX/UI Design        Evening 432.87  18548       8.06 149,523.45 0.00
# 3       UX/UI Design        Morning 935.34  18548       8.06 149,523.45 0.01
# 4      Web Developer        Morning 726.10  18548       8.06 149,523.45 0.01
#
#      B     T  APC     CLTV    LTV      CAC      Revenue           CM
# 0  112   764 6.82 2,494.55  15.06 1,335.03   279,390.00   129,866.55
# 1  349  2056 5.89 5,486.10 103.23   428.43 1,914,650.00 1,765,126.55
# 2   58   284 4.90 2,119.57   6.63 2,577.99   122,935.00   -26,588.45
# 3  169   886 5.24 4,903.61  44.68   884.75   828,710.00   679,186.55
# 4  135   505 3.74 2,716.15  19.77 1,107.58   366,680.00   217,156.55

# %% [raw]
# Рассчитаем юнит-экономику по сегментам. Сделаем группировку по наименованию продукта и по типу обучения для каждого продукта.
# Будем анализировать юнит-экономику с точки зрения того, что каждая комбинация Product + Edication Type = отдельный продукт:

# %%
def simulate_metric_changes_by_product(df, product_name, delta_pct=10):
    increase_factor = 1 + delta_pct / 100
    decrease_factor = 1 - delta_pct / 100

    # Классификация метрик
    metrics = ['AOV', 'UA', 'AC', 'LTC (CPA)', 'C1', 'B', 'T', 'APC', 'CLTV', 'LTV', 'Revenue', 'CM']
    metrics_to_increase = ['AOV', 'UA', 'C1', 'APC']
    metrics_to_decrease = ['LTC (CPA)']
    metrics_fixed = ['AC', 'B', 'T', 'CLTV', 'LTV']  # рассчитываются, но не меняются напрямую
    row_metrics = metrics_to_increase + metrics_to_decrease

    # Получение базовых значений
    base_row = df[df['Product'] == product_name].iloc[0]
    base_values = base_row[metrics].to_dict()

    # Подготовка таблицы
    table = {
        'Metric ↑ / ↓ →': ['Base'] + [
            f'{m} +{delta_pct}%' if m in metrics_to_increase else f'{m} -{delta_pct}%' for m in row_metrics
        ]
    }

    for column_metric in metrics:
        values = [base_values[column_metric]]

        for changed_metric in row_metrics:
            temp = base_values.copy()

            # Применение изменений
            if changed_metric in metrics_to_increase:
                temp[changed_metric] *= increase_factor
            elif changed_metric in metrics_to_decrease:
                temp[changed_metric] *= decrease_factor

            # Пересчёт зависимых метрик
            temp['CLTV'] = temp['AOV'] * temp['APC']
            temp['LTV'] = temp['CLTV'] * temp['C1']
            temp['CM'] = temp['UA'] * (temp['LTV'] - temp['LTC (CPA)'])
            temp['Revenue'] = temp['AOV'] * temp['APC'] * temp['B']

            values.append(temp[column_metric])

        table[column_metric] = values

    return pd.DataFrame(table)

# %%
simulate_metric_changes_by_product(product_df, 'Digital Marketing', delta_pct=10)
# Out:
#    Metric ↑ / ↓ →    AOV        UA         AC  LTC (CPA)   C1    B     T  APC  \
# 0            Base 783.95 18,548.00 149,523.45       8.06 0.03  468  2886 6.17
# 1        AOV +10% 862.35 18,548.00 149,523.45       8.06 0.03  468  2886 6.17
# 2         UA +10% 783.95 20,402.80 149,523.45       8.06 0.03  468  2886 6.17
# 3         C1 +10% 783.95 18,548.00 149,523.45       8.06 0.03  468  2886 6.17
# 4        APC +10% 783.95 18,548.00 149,523.45       8.06 0.03  468  2886 6.78
# 5  LTC (CPA) -10% 783.95 18,548.00 149,523.45       7.26 0.03  468  2886 6.17
#
#       CLTV    LTV      Revenue           CM
# 0 4,834.38 121.98 2,262,490.00 2,112,966.55
# 1 5,317.82 134.18 2,488,739.00 2,339,215.55
# 2 4,834.38 121.98 2,262,490.00 2,324,263.21
# 3 4,834.38 134.18 2,262,490.00 2,339,215.55
# 4 5,317.82 134.18 2,488,739.00 2,339,215.55
# 5 4,834.38 121.98 2,262,490.00 2,127,918.90

# %%
simulate_metric_changes_by_product(product_df, 'UX/UI Design', delta_pct=10)
# Out:
#    Metric ↑ / ↓ →    AOV        UA         AC  LTC (CPA)   C1    B     T  APC  \
# 0            Base 813.37 18,548.00 149,523.45       8.06 0.01  226  1170 5.18
# 1        AOV +10% 894.71 18,548.00 149,523.45       8.06 0.01  226  1170 5.18
# 2         UA +10% 813.37 20,402.80 149,523.45       8.06 0.01  226  1170 5.18
# 3         C1 +10% 813.37 18,548.00 149,523.45       8.06 0.01  226  1170 5.18
# 4        APC +10% 813.37 18,548.00 149,523.45       8.06 0.01  226  1170 5.69
# 5  LTC (CPA) -10% 813.37 18,548.00 149,523.45       7.26 0.01  226  1170 5.18
#
#       CLTV   LTV      Revenue         CM
# 0 4,210.82 51.31   951,645.00 802,121.55
# 1 4,631.90 56.44 1,046,809.50 897,286.05
# 2 4,210.82 51.31   951,645.00 882,333.71
# 3 4,210.82 56.44   951,645.00 897,286.05
# 4 4,631.90 56.44 1,046,809.50 897,286.05
# 5 4,210.82 51.31   951,645.00 817,073.90

# %%
simulate_metric_changes_by_product(product_df, 'Web Developer', delta_pct=10)
# Out:
#    Metric ↑ / ↓ →    AOV        UA         AC  LTC (CPA)   C1    B    T  APC  \
# 0            Base 726.10 18,548.00 149,523.45       8.06 0.01  135  505 3.74
# 1        AOV +10% 798.71 18,548.00 149,523.45       8.06 0.01  135  505 3.74
# 2         UA +10% 726.10 20,402.80 149,523.45       8.06 0.01  135  505 3.74
# 3         C1 +10% 726.10 18,548.00 149,523.45       8.06 0.01  135  505 3.74
# 4        APC +10% 726.10 18,548.00 149,523.45       8.06 0.01  135  505 4.11
# 5  LTC (CPA) -10% 726.10 18,548.00 149,523.45       7.26 0.01  135  505 3.74
#
#       CLTV   LTV    Revenue         CM
# 0 2,716.15 19.77 366,680.00 217,156.55
# 1 2,987.76 21.75 403,348.00 253,824.55
# 2 2,716.15 19.77 366,680.00 238,872.21
# 3 2,716.15 21.75 366,680.00 253,824.55
# 4 2,987.76 21.75 403,348.00 253,824.55
# 5 2,716.15 19.77 366,680.00 232,108.90

# %% [raw]
# Рассчитаем юнит-экономику по сегментам. Сделаем группировку по наименованию продукта и по типу обучения для каждого продукта.
# Будем анализировать юнит-экономику с точки зрения того, что каждая комбинация Product + Edication Type = отдельный продукт:

# %%
def change_metrics_table(df, product, education_type, delta_pct=10):
    increase_factor = 1 + delta_pct / 100
    decrease_factor = 1 - delta_pct / 100

    # Классификация метрик
    metrics = ['AOV', 'UA', 'AC', 'LTC (CPA)', 'C1', 'B', 'T', 'APC', 'CLTV', 'LTV', 'Revenue', 'CM']
    metrics_to_increase = ['AOV', 'UA', 'C1', 'APC']
    metrics_to_decrease = ['LTC (CPA)']
    metrics_fixed = ['AC', 'B', 'T', 'CLTV', 'LTV']  # рассчитываются, но не меняются напрямую
    row_metrics = metrics_to_increase + metrics_to_decrease

    # Получение базовых значений
    base = df[
        (df['Product'] == product) &
        (df['Education Type'] == education_type)
    ].iloc[0]
    base_values = base[metrics].to_dict()

    # Подготовка таблицы
    table = {
        'Метрика ↑ / ↓ Метрика →': ['Base'] + [
            f'{m} +{delta_pct}%' if m in metrics_to_increase else f'{m} -{delta_pct}%' for m in row_metrics
        ]
    }

    for col_metric in metrics:
        col_values = [base_values[col_metric]]

        for row_metric in row_metrics:
            temp = base_values.copy()

            # Изменение выбранной метрики
            if row_metric in metrics_to_increase:
                temp[row_metric] *= increase_factor
            elif row_metric in metrics_to_decrease:
                temp[row_metric] *= decrease_factor

            # Пересчёт зависимых метрик
            temp['CLTV'] = temp['AOV'] * temp['APC']
            temp['LTV'] = temp['CLTV'] * temp['C1']
            temp['CM'] = temp['UA'] * (temp['LTV'] - temp['LTC (CPA)'])
            temp['Revenue'] = temp['AOV'] * temp['APC'] * temp['B']

            col_values.append(temp[col_metric])

        table[col_metric] = col_values

    return pd.DataFrame(table)

# %%
change_metrics_table(unit_df, 'Digital Marketing', 'Evening', delta_pct=10)
# pd.set_option('display.float_format', '{:,.2f}'.format)
# Out:
#   Метрика ↑ / ↓ Метрика →    AOV        UA         AC  LTC (CPA)   C1    B  \
# 0                    Base 365.69 18,548.00 149,523.45       8.06 0.01  112
# 1                AOV +10% 402.26 18,548.00 149,523.45       8.06 0.01  112
# 2                 UA +10% 365.69 20,402.80 149,523.45       8.06 0.01  112
# 3                 C1 +10% 365.69 18,548.00 149,523.45       8.06 0.01  112
# 4                APC +10% 365.69 18,548.00 149,523.45       8.06 0.01  112
# 5          LTC (CPA) -10% 365.69 18,548.00 149,523.45       7.26 0.01  112
#
#      T  APC     CLTV   LTV    Revenue         CM
# 0  764 6.82 2,494.55 15.06 279,390.00 129,866.55
# 1  764 6.82 2,744.01 16.57 307,329.00 157,805.55
# 2  764 6.82 2,494.55 15.06 279,390.00 142,853.20
# 3  764 6.82 2,494.55 16.57 279,390.00 157,805.55
# 4  764 7.50 2,744.01 16.57 307,329.00 157,805.55
# 5  764 6.82 2,494.55 15.06 279,390.00 144,818.89

# %%
change_metrics_table(unit_df, 'Digital Marketing', 'Morning', delta_pct=10)
# Out:
#   Метрика ↑ / ↓ Метрика →      AOV        UA         AC  LTC (CPA)   C1    B  \
# 0                    Base   931.25 18,548.00 149,523.45       8.06 0.02  349
# 1                AOV +10% 1,024.38 18,548.00 149,523.45       8.06 0.02  349
# 2                 UA +10%   931.25 20,402.80 149,523.45       8.06 0.02  349
# 3                 C1 +10%   931.25 18,548.00 149,523.45       8.06 0.02  349
# 4                APC +10%   931.25 18,548.00 149,523.45       8.06 0.02  349
# 5          LTC (CPA) -10%   931.25 18,548.00 149,523.45       7.26 0.02  349
#
#       T  APC     CLTV    LTV      Revenue           CM
# 0  2056 5.89 5,486.10 103.23 1,914,650.00 1,765,126.55
# 1  2056 5.89 6,034.71 113.55 2,106,115.00 1,956,591.55
# 2  2056 5.89 5,486.10 103.23 1,914,650.00 1,941,639.21
# 3  2056 5.89 5,486.10 113.55 1,914,650.00 1,956,591.55
# 4  2056 6.48 6,034.71 113.55 2,106,115.00 1,956,591.55
# 5  2056 5.89 5,486.10 103.23 1,914,650.00 1,780,078.89

# %%
change_metrics_table(unit_df, 'UX/UI Design', 'Morning', delta_pct=10)
# Out:
#   Метрика ↑ / ↓ Метрика →      AOV        UA         AC  LTC (CPA)   C1    B  \
# 0                    Base   935.34 18,548.00 149,523.45       8.06 0.01  169
# 1                AOV +10% 1,028.87 18,548.00 149,523.45       8.06 0.01  169
# 2                 UA +10%   935.34 20,402.80 149,523.45       8.06 0.01  169
# 3                 C1 +10%   935.34 18,548.00 149,523.45       8.06 0.01  169
# 4                APC +10%   935.34 18,548.00 149,523.45       8.06 0.01  169
# 5          LTC (CPA) -10%   935.34 18,548.00 149,523.45       7.26 0.01  169
#
#      T  APC     CLTV   LTV    Revenue         CM
# 0  886 5.24 4,903.61 44.68 828,710.00 679,186.55
# 1  886 5.24 5,393.97 49.15 911,581.00 762,057.55
# 2  886 5.24 4,903.61 44.68 828,710.00 747,105.21
# 3  886 5.24 4,903.61 49.15 828,710.00 762,057.55
# 4  886 5.77 5,393.97 49.15 911,581.00 762,057.55
# 5  886 5.24 4,903.61 44.68 828,710.00 694,138.90

# %%
change_metrics_table(unit_df, 'UX/UI Design', 'Evening', delta_pct=10)
# Out:
#   Метрика ↑ / ↓ Метрика →    AOV        UA         AC  LTC (CPA)   C1   B  \
# 0                    Base 432.87 18,548.00 149,523.45       8.06 0.00  58
# 1                AOV +10% 476.16 18,548.00 149,523.45       8.06 0.00  58
# 2                 UA +10% 432.87 20,402.80 149,523.45       8.06 0.00  58
# 3                 C1 +10% 432.87 18,548.00 149,523.45       8.06 0.00  58
# 4                APC +10% 432.87 18,548.00 149,523.45       8.06 0.00  58
# 5          LTC (CPA) -10% 432.87 18,548.00 149,523.45       7.26 0.00  58
#
#      T  APC     CLTV  LTV    Revenue         CM
# 0  284 4.90 2,119.57 6.63 122,935.00 -26,588.45
# 1  284 4.90 2,331.53 7.29 135,228.50 -14,294.95
# 2  284 4.90 2,119.57 6.63 122,935.00 -29,247.30
# 3  284 4.90 2,119.57 7.29 122,935.00 -14,294.95
# 4  284 5.39 2,331.53 7.29 135,228.50 -14,294.95
# 5  284 4.90 2,119.57 6.63 122,935.00 -11,636.11

# %%
change_metrics_table(unit_df, 'UX/UI Design', 'Morning', delta_pct=10)
# Out:
#   Метрика ↑ / ↓ Метрика →      AOV        UA         AC  LTC (CPA)   C1    B  \
# 0                    Base   935.34 18,548.00 149,523.45       8.06 0.01  169
# 1                AOV +10% 1,028.87 18,548.00 149,523.45       8.06 0.01  169
# 2                 UA +10%   935.34 20,402.80 149,523.45       8.06 0.01  169
# 3                 C1 +10%   935.34 18,548.00 149,523.45       8.06 0.01  169
# 4                APC +10%   935.34 18,548.00 149,523.45       8.06 0.01  169
# 5          LTC (CPA) -10%   935.34 18,548.00 149,523.45       7.26 0.01  169
#
#      T  APC     CLTV   LTV    Revenue         CM
# 0  886 5.24 4,903.61 44.68 828,710.00 679,186.55
# 1  886 5.24 5,393.97 49.15 911,581.00 762,057.55
# 2  886 5.24 4,903.61 44.68 828,710.00 747,105.21
# 3  886 5.24 4,903.61 49.15 828,710.00 762,057.55
# 4  886 5.77 5,393.97 49.15 911,581.00 762,057.55
# 5  886 5.24 4,903.61 44.68 828,710.00 694,138.90

# %%
change_metrics_table(unit_df, 'Web Developer', 'Morning', delta_pct=10)
# Out:
#   Метрика ↑ / ↓ Метрика →    AOV        UA         AC  LTC (CPA)   C1    B  \
# 0                    Base 726.10 18,548.00 149,523.45       8.06 0.01  135
# 1                AOV +10% 798.71 18,548.00 149,523.45       8.06 0.01  135
# 2                 UA +10% 726.10 20,402.80 149,523.45       8.06 0.01  135
# 3                 C1 +10% 726.10 18,548.00 149,523.45       8.06 0.01  135
# 4                APC +10% 726.10 18,548.00 149,523.45       8.06 0.01  135
# 5          LTC (CPA) -10% 726.10 18,548.00 149,523.45       7.26 0.01  135
#
#      T  APC     CLTV   LTV    Revenue         CM
# 0  505 3.74 2,716.15 19.77 366,680.00 217,156.55
# 1  505 3.74 2,987.76 21.75 403,348.00 253,824.55
# 2  505 3.74 2,716.15 19.77 366,680.00 238,872.21
# 3  505 3.74 2,716.15 21.75 366,680.00 253,824.55
# 4  505 4.11 2,987.76 21.75 403,348.00 253,824.55
# 5  505 3.74 2,716.15 19.77 366,680.00 232,108.90
