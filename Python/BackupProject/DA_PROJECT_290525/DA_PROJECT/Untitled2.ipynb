# %%
import pandas as pd

deals = pd.read_pickle("deals_cleaned_v3.pkl")
deals
# Out:
#                         Id  Deal Owner Name Closing Date            Quality  \
# 0      5805028000056864695         Ben Hall          NaT         B - Medium
# 1      5805028000056859489    Ulysses Adams          NaT         B - Medium
# 2      5805028000056832357    Ulysses Adams   2024-06-21     D - Non Target
# 3      5805028000056824246         Eva Kent   2024-06-21  E - Non Qualified
# 4      5805028000056873292         Ben Hall   2024-06-21     D - Non Target
# ...                    ...              ...          ...                ...
# 21406  5805028000050001603   Quincy Vincent   2024-05-15  E - Non Qualified
# 21407  5805028000053787195  Paula Underwood   2024-06-06  E - Non Qualified
# 21408  5805028000054823001   Quincy Vincent   2024-06-12  E - Non Qualified
# 21409  5805028000056685164    Charlie Davis   2024-06-20  E - Non Qualified
# 21410  5805028000056705395    Ulysses Adams   2024-06-20  E - Non Qualified
#
# ...

# %%
deals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21411 entries, 0 to 21410
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    21411 non-null  object
#  1   Deal Owner Name       21382 non-null  object
#  2   Closing Date          16685 non-null  datetime64[ns]
#  3   Quality               21411 non-null  category
#  4   Stage                 21411 non-null  category
#  5   Lost Reason           15942 non-null  category
#  6   Page                  20342 non-null  object
#  7   Campaign              16006 non-null  category
#  8   SLA                   15504 non-null  timedelta64[ns]
#  9   Content               14101 non-null  object
#  10  Term                  12387 non-null  object
#  11  Source                21411 non-null  object
#  12  Payment Type          496 non-null    category
#  13  Product               3592 non-null   category
# ...

# %%
import pandas as pd

deals = pd.read_pickle("deals_cleaned.pkl")
deals
# Out:
#                         Id  Deal Owner Name Closing Date            Quality  \
# 0      5805028000056864695         Ben Hall          NaT                NaN
# 1      5805028000056859489    Ulysses Adams          NaT                NaN
# 2      5805028000056832357    Ulysses Adams   2024-06-21     D - Non Target
# 3      5805028000056824246         Eva Kent   2024-06-21  E - Non Qualified
# 4      5805028000056873292         Ben Hall   2024-06-21     D - Non Target
# ...                    ...              ...          ...                ...
# 21406  5805028000050001603   Quincy Vincent   2024-05-15  E - Non Qualified
# 21407  5805028000053787195  Paula Underwood   2024-06-06  E - Non Qualified
# 21408  5805028000054823001   Quincy Vincent   2024-06-12  E - Non Qualified
# 21409  5805028000056685164    Charlie Davis   2024-06-20  E - Non Qualified
# 21410  5805028000056705395    Ulysses Adams   2024-06-20  E - Non Qualified
#
# ...

# %%
# setting to display columns as much as possible
pd.set_option('display.max_columns', None)

# %%
deals[(deals['Stage'] == 'Payment Done') & (deals['Offer Total Amount'].isna())]
# Out:
#                         Id Deal Owner Name Closing Date            Quality  \
# 13854  5805028000022036007             NaN   2023-12-19  E - Non Qualified
# 15052  5805028000019345087        John Doe   2024-05-01  E - Non Qualified
# 16124  5805028000017534101      Nina Scott   2023-11-25            C - Low
# 17073  5805028000014229195    Kevin Parker   2023-11-06            C - Low
# 17261  5805028000013759117    Kevin Parker   2023-11-02         B - Medium
# 17444  5805028000013173143    Kevin Parker   2023-10-29     D - Non Target
# 17588  5805028000012719036    Kevin Parker   2023-10-28     D - Non Target
# 17727  5805028000012018001    Kevin Parker   2023-10-25         B - Medium
# 17802  5805028000011624813    Kevin Parker   2023-10-23            C - Low
# 18167  5805028000010414749    Kevin Parker   2023-10-16            C - Low
# 18375  5805028000010015047    Kevin Parker   2023-10-12            C - Low
# ...

# %%
deals[(deals['Stage'] == 'Payment Done') & (deals['Initial Amount Paid'].isna())]
# Out:
#                         Id Deal Owner Name Closing Date            Quality  \
# 13854  5805028000022036007             NaN   2023-12-19  E - Non Qualified
# 15052  5805028000019345087        John Doe   2024-05-01  E - Non Qualified
# 16124  5805028000017534101      Nina Scott   2023-11-25            C - Low
# 17073  5805028000014229195    Kevin Parker   2023-11-06            C - Low
# 17261  5805028000013759117    Kevin Parker   2023-11-02         B - Medium
# 17444  5805028000013173143    Kevin Parker   2023-10-29     D - Non Target
# 17588  5805028000012719036    Kevin Parker   2023-10-28     D - Non Target
# 17727  5805028000012018001    Kevin Parker   2023-10-25         B - Medium
# 17802  5805028000011624813    Kevin Parker   2023-10-23            C - Low
# 18167  5805028000010414749    Kevin Parker   2023-10-16            C - Low
# 18375  5805028000010015047    Kevin Parker   2023-10-12            C - Low
# ...

# %%
deals[(deals['Stage'] == 'Payment Done') & (deals['Offer Total Amount'].notna())]
# Out:
#                         Id Deal Owner Name Closing Date         Quality  \
# 463    5805028000055502703        Eva Kent   2024-06-18      B - Medium
# 473    5805028000055524315        Ben Hall   2024-06-19        A - High
# 491    5805028000055524040        Ben Hall   2024-06-23      B - Medium
# 824    5805028000054664018        Ben Hall   2024-06-19  D - Non Target
# 1029   5805028000054257317  Quincy Vincent   2024-06-17      B - Medium
# ...                    ...             ...          ...             ...
# 21034  5805028000002302112    Julia Nelson   2023-07-19         C - Low
# 21087  5805028000001987082    Julia Nelson   2023-07-17         C - Low
# 21130  5805028000001885076      Jane Smith   2023-08-31        A - High
# 21265  5805028000001401001   Oliver Taylor   2023-07-16      B - Medium
# 21296  5805028000000947046   Oliver Taylor   2023-07-12      B - Medium
#
#               Stage                  Lost Reason  \
# 463    Payment Done                          NaN
# ...

# %%
len(deals[(deals['Stage'] == 'Payment Done') & (deals['Initial Amount Paid'].notna())])
# Out:
# 840

# %%
deals[(deals['Stage'] == 'Payment Done')]
# Out:
#                         Id Deal Owner Name Closing Date         Quality  \
# 463    5805028000055502703        Eva Kent   2024-06-18      B - Medium
# 473    5805028000055524315        Ben Hall   2024-06-19        A - High
# 491    5805028000055524040        Ben Hall   2024-06-23      B - Medium
# 824    5805028000054664018        Ben Hall   2024-06-19  D - Non Target
# 1029   5805028000054257317  Quincy Vincent   2024-06-17      B - Medium
# ...                    ...             ...          ...             ...
# 21034  5805028000002302112    Julia Nelson   2023-07-19         C - Low
# 21087  5805028000001987082    Julia Nelson   2023-07-17         C - Low
# 21130  5805028000001885076      Jane Smith   2023-08-31        A - High
# 21265  5805028000001401001   Oliver Taylor   2023-07-16      B - Medium
# 21296  5805028000000947046   Oliver Taylor   2023-07-12      B - Medium
#
#               Stage                  Lost Reason  \
# 463    Payment Done                          NaN
# ...
