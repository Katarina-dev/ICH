# %% [markdown]
# # Анализ эффективности работы отдела продаж

# %% [markdown]
# ## 1. Оцените эффективность отдельных владельцев сделок и рекламных кампаний с точки зрения количества обработанных сделок, коэффициента конверсии и общей суммы продаж.

# %%
import pandas as pd

deals_df = pd.read_pickle("deals_cleaned.pkl")

# %%
# add a flag for the success of the deals is_success
deals_df['is_success'] = (deals_df['Stage'] == 'Payment Done') & (deals_df['Offer Total Amount'].notna())

# %%
# create a summary table by owners, total number of deals, number of successful deals, conversion and sales amount
owners_effect = deals_df.groupby('Deal Owner Name').agg(
    total_deals=('Id', 'count'), # all deals
    success_deals=('is_success', 'sum'),# successful deals
    conversion_rate=('is_success', lambda x: round(x.sum() / x.count(), 2)),
    total_paid=('Offer Total Amount', 'sum')
).reset_index().sort_values(by='total_paid', ascending=False)

# %%
owners_effect
# Out:
#     Deal Owner Name  total_deals  success_deals  conversion_rate  total_paid
# 21    Ulysses Adams         2150            140             0.07   5106800.0
# 5     Charlie Davis         2929            148             0.05   3822500.0
# 12     Julia Nelson         2196             93             0.04   3575311.0
# 17  Paula Underwood         1855             93             0.05   2842000.0
# 22    Victor Barnes         1229             44             0.04   2196800.0
# 2          Ben Hall         1344             46             0.03   2030800.0
# 15       Nina Scott         1280             45             0.04   1951400.0
# 18   Quincy Vincent         1878             65             0.03   1788900.0
# 16    Oliver Taylor          163             50             0.31   1660500.0
# 10       Jane Smith          981             31             0.03   1468500.0
# 4      Cara Iverson         1055             27             0.03    923000.0
# 13     Kevin Parker          556             26             0.05    741400.0
# 6       Diana Evans          998              1             0.00    562500.0
# 7          Eva Kent          459             18             0.04    554300.0
# 9        Ian Miller          489              8             0.02    299000.0
# 14    Mason Roberts          268              3             0.01    222000.0
# 19     Rachel White          868              0             0.00     33500.0
# 8       George King           94              2             0.02     33500.0
# 3         Bob Brown          327              0             0.00     13500.0
# 11         John Doe           19              0             0.00      7500.0
# 1         Amy Green           63              0             0.00         0.0
# 0     Alice Johnson           25              0             0.00         0.0
# 20        Sam Young           66              0             0.00         0.0
# 23      Wendy Clark            2              0             0.00         0.0
# 24      Xander Dean            3              0             0.00         0.0
# 25     Yara Edwards           84              0             0.00         0.0
# 26   Zachary Foster            1              0             0.00         0.0

# %%
owners_not_null_success = owners_effect[owners_effect['success_deals'] > 0].sort_values(by='success_deals', ascending=False)

# Строим гистограмму
plt.figure(figsize=(12, 7))
bars = plt.bar(
    owners_not_null_success['Deal Owner Name'],
    owners_not_null_success['success_deals'],
    color='lightblue'
)

# Подписи на столбиках
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        height + 0.5,
        str(int(height)),
        ha='center',
        va='bottom',
        fontsize=10,
        color='black',
        fontweight='bold'
    )

plt.xlabel('Deal Owner Name')
plt.ylabel('Count')
plt.title('Number of successful deals by qwner')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Visualization of the efficiency of deal owners in terms of sales amounts and conversions
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
import seaborn as sns

# Filtering out owners of deals with zero sales
filtered_owners = owners_effect[owners_effect['total_paid'] > 0]
sorted_by_conversion = filtered_owners.sort_values('conversion_rate', ascending=False)

# filtered_owners['total_paid'] = filtered_owners['total_paid'].astype(float)

# Setting up visualizations
sns.set(style="whitegrid")
fig, axes = plt.subplots(1, 2, figsize=(16, 6))  # 1 row, 2 columns
fig.suptitle("Assessing the effectiveness of deal owners", fontsize=18)

# Sales total by owner
sns.barplot(data=filtered_owners, x='total_paid', y='Deal Owner Name',
            ax=axes[0])
axes[0].set_title("Total sales by owner")

# Format the X-axis: add thousand separators
axes[0].xaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{x:,.0f}'))

axes[0].set_xlabel("Sales amount")
axes[0].set_ylabel("Owner")

# Conversion by Owner
sns.barplot(data=sorted_by_conversion, x='conversion_rate', y='Deal Owner Name',
            ax=axes[1])
axes[1].set_title("Conversion rate by owner")
axes[1].set_xlabel("Conversion")
axes[1].set_ylabel("")

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Calculate Average closing time of all deals by owner
import pandas as pd

# Average closing time of all deals by owner
avg_closing_time = deals_df.groupby('Deal Owner Name', observed=False)['Create_to_Close_Days'].mean().reset_index()
avg_closing_time.columns = ['Deal Owner Name', 'Avg Closing Time (days)']

print(avg_closing_time)
# Out:
#     Deal Owner Name  Avg Closing Time (days)
# 0     Alice Johnson                 1.120000
# 1         Amy Green                 1.827586
# 2          Ben Hall                 3.283139
# 3         Bob Brown                 2.113150
# 4      Cara Iverson                 8.216107
# 5     Charlie Davis                18.794849
# 6       Diana Evans                 8.605747
# 7          Eva Kent                 4.779592
# 8       George King                17.944444
# 9        Ian Miller                17.873894
# 10       Jane Smith                17.201954
# 11         John Doe                21.714286
# 12     Julia Nelson                17.846012
# 13     Kevin Parker                11.038911
# 14    Mason Roberts                14.833333
# 15       Nina Scott                22.239270
# 16    Oliver Taylor                34.079470
# 17  Paula Underwood                11.318118
# 18   Quincy Vincent                13.711923
# 19     Rachel White                 2.516605
# 20        Sam Young                 2.649123
# 21    Ulysses Adams                16.465072
# 22    Victor Barnes                 5.134768
# 23      Wendy Clark                 1.000000
# 24      Xander Dean                10.333333
# 25     Yara Edwards                 6.440000
# 26   Zachary Foster                      NaN

# %%
# visualize the Average closing time of all transactions by owners

import matplotlib.pyplot as plt

# Sort: Fastest to Slowest
avg_closing_time = avg_closing_time.dropna().sort_values(by='Avg Closing Time (days)', ascending=False)

plt.figure(figsize=(12, 8))
plt.barh(
    avg_closing_time['Deal Owner Name'], 
    avg_closing_time['Avg Closing Time (days)'], 
    color='skyblue'
)
plt.xlabel('Average deal closing time (days)')
plt.ylabel('Owner of the deals')
plt.title('Average deal closing time by owner for all deals')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Filter deals of Oliver Taylor
oliver_deals = deals_df[deals_df['Deal Owner Name'] == 'Oliver Taylor']

#Find the deal with the longest closing time
longest_deal_oliver = oliver_deals.loc[oliver_deals['Create_to_Close_Days'].idxmax()]

print(longest_deal_oliver)
# Out:
# Id                      5805028000008783070
# Deal Owner Name               Oliver Taylor
# Closing Date            2024-06-12 00:00:00
# Quality                          B - Medium
# Stage                                  Lost
# Lost Reason                Changed Decision
# Campaign                     07.07.23lal_de
# SLA                         1 days 03:47:04
# Source                         facebook ads
# Payment Type                            NaN
# Product                   Digital Marketing
# Education Type                      Morning
# Created Time            2023-09-24 07:19:00
# Course duration                          11
# Months of study                        <NA>
# Initial Amount Paid                  1000.0
# Offer Total Amount                  11000.0
# Contact Name            5805028000004861333
# City                                    NaN
# German level                             B2
# Create_to_Close_Days                  262.0
# Latitude                                NaN
# Longitude                               NaN
# SLA_range               Very slow (>60 min)
# is_success                            False
# Name: 18886, dtype: object

# %%
# Exclude deals with unknown closing time
oliver_deals = oliver_deals.dropna(subset=['Create_to_Close_Days'])

# Sort in descending order
oliver_sorted = oliver_deals.sort_values(by='Create_to_Close_Days', ascending=False)

print(oliver_sorted[['Id', 'Create_to_Close_Days', 'Stage', 'Created Time', 'Closing Date', 'Offer Total Amount']].head(20).to_string(index=False))
# Out:
#                  Id  Create_to_Close_Days        Stage        Created Time Closing Date  Offer Total Amount
# 5805028000008783070                 262.0         Lost 2023-09-24 07:19:00   2024-06-12             11000.0
# 5805028000011973051                 246.0         Lost 2023-10-17 01:30:00   2024-06-19             11000.0
# 5805028000013030425                 234.0         Lost 2023-10-21 14:25:00   2024-06-11              5000.0
# 5805028000006448447                 221.0         Lost 2023-09-01 10:26:00   2024-04-09             11500.0
# 5805028000006811346                 217.0         Lost 2023-09-06 19:42:00   2024-04-10             11500.0
# 5805028000004984062                 214.0         Lost 2023-08-17 17:25:00   2024-03-18             11500.0
# 5805028000013204761                 214.0         Lost 2023-10-22 21:14:00   2024-05-23             11000.0
# 5805028000003669279                 203.0 Payment Done 2023-08-03 14:11:00   2024-02-22             11000.0
# 5805028000008975027                 197.0         Lost 2023-09-25 18:09:00   2024-04-09             11000.0
# 5805028000015866286                 195.0         Lost 2023-11-08 10:38:00   2024-05-21             11000.0
# 5805028000019618892                 169.0         Lost 2023-12-05 11:42:00   2024-05-22             11000.0
# 5805028000013465196                 168.0         Lost 2023-10-24 20:40:00   2024-04-09             11500.0
# 5805028000008139016                 142.0         Lost 2023-09-19 17:49:00   2024-02-08             11000.0
# 5805028000018441341                 135.0         Lost 2023-11-22 18:14:00   2024-04-05             11000.0
# 5805028000022397296                 107.0         Lost 2023-12-20 21:43:00   2024-04-05             11000.0
# 5805028000018376841                 103.0 Payment Done 2023-11-23 13:03:00   2024-03-05              2500.0
# 5805028000001517025                  99.0         Lost 2023-07-11 18:41:00   2023-10-18             11500.0
# 5805028000003307001                  98.0         Lost 2023-07-27 18:59:00   2023-11-02             11500.0
# 5805028000022912137                  96.0         Lost 2023-12-23 22:55:00   2024-03-28             11000.0
# 5805028000015712036                  94.0         Lost 2023-11-07 14:50:00   2024-02-09             11000.0

# %%
# # Фильтруем сделки со статусом "Payment Done"
# deals_success = deals_df[deals_df['is_success']]

# # Среднее время закрытия по владельцам для успешных сделок
# avg_closing_time_success = deals_success.groupby('Deal Owner Name', observed=False)['Create_to_Close_Days'].mean().reset_index()
# avg_closing_time_success.columns = ['Deal Owner Name', 'Avg Closing Time (days)']

# Average closing time by owner for successful deals
avg_closing_time_success = (
    deals_df[deals_df['is_success']]
    .groupby('Deal Owner Name', observed=False)['Create_to_Close_Days']
    .mean()
    .reset_index(name='Avg Closing Time (days)')
)

# Sort by time of deals
avg_closing_time_success = avg_closing_time_success.dropna().sort_values('Avg Closing Time (days)', ascending=False)

plt.figure(figsize=(12, 8))
plt.barh(
    avg_closing_time_success['Deal Owner Name'], 
    avg_closing_time_success['Avg Closing Time (days)'], 
    color='skyblue'
)
plt.xlabel('Average time to close successful deals (days)')
plt.ylabel('Owner of the deals')
plt.title('Average time to close successful deals (Payment Done) by owners')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Filter deals of Diana Evans
diana_successful_deals = deals_df[
    (deals_df['Deal Owner Name'] == 'Diana Evans') & 
    (deals_df['is_success'])
]
diana_sorted = diana_successful_deals.sort_values(by='Create_to_Close_Days', ascending=False)

print(diana_sorted[['Id', 'Create_to_Close_Days', 'Stage', 'Created Time', 'Closing Date', 'Offer Total Amount']].to_string(index=False))
# Out:
#                  Id  Create_to_Close_Days        Stage        Created Time Closing Date  Offer Total Amount
# 5805028000003814064                   0.0 Payment Done 2023-08-04 15:53:00   2023-08-04              3500.0

# %%
import matplotlib.pyplot as plt

# Grouping: average time and number of successful trades
avg_closing_time_success = (
    deals_df[deals_df['is_success']]
    .groupby('Deal Owner Name', observed=False)
    .agg(
        avg_closing_time=('Create_to_Close_Days', 'mean'),
        success_deals_count=('Id', 'count')
    )
    .reset_index()
    .dropna()
    .sort_values('avg_closing_time', ascending=False)
)

# Построение графика с двумя осями
fig, ax1 = plt.subplots(figsize=(12, 8))

# Первая ось — среднее время (бар-чарт)
ax1.barh(
    avg_closing_time_success['Deal Owner Name'],
    avg_closing_time_success['avg_closing_time'],
    color='skyblue',
    label='Avg Closing Time (days)'
)
ax1.set_xlabel('Avg Closing Time (days)')
ax1.set_ylabel('Deal Owner Name')
ax1.set_title('Avg Closing Time & Number of Success Deals by Owner')
ax1.grid(axis='x', linestyle='--', alpha=0.7)

# The second axis is the number of transactions (dots and signatures)
ax2 = ax1.twiny()
owners = avg_closing_time_success['Deal Owner Name']
counts = avg_closing_time_success['success_deals_count']

# Line and dots
ax2.plot(counts, owners, 'o-', color='darkorange', linewidth=2, markersize=6, label='Success Deals Count')
ax2.set_xlabel('Number of Success Deals')

# Point labels
for x, y in zip(counts, owners):
    ax2.text(x + 1.0, y, str(x), va='center', fontsize=9, color='#4B2008', fontweight='bold')

# Легенды
ax1.legend(loc='lower right')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Filtering deals with the status 'Lost'
lost_deals_df = deals_df[deals_df['Stage'] == 'Lost']

# Average closing time by owner for lost deals
avg_closing_time_lost = lost_deals_df.groupby('Deal Owner Name', observed=False)['Create_to_Close_Days'].mean().reset_index()
avg_closing_time_lost.columns = ['Deal Owner Name', 'Avg Closing Time (days)']

avg_closing_time_lost = avg_closing_time_lost.sort_values('Avg Closing Time (days)', ascending=False)

plt.figure(figsize=(12, 8))
plt.barh(
    avg_closing_time_lost['Deal Owner Name'], 
    avg_closing_time_lost['Avg Closing Time (days)'], 
    color='skyblue'
)
plt.xlabel('Average deal closing time (days)')
plt.ylabel('Owner of the transaction')
plt.title('Average time to close lost deals (Payment Done) by owner')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Filter deals of Diana Evans
john_lost_deals = deals_df[
    (deals_df['Deal Owner Name'] == 'John Doe') & 
    (deals_df['Stage'] == 'Lost')
]
john_lost_sorted = john_lost_deals.sort_values(by='Create_to_Close_Days', ascending=False)

print(john_lost_sorted[['Id', 'Create_to_Close_Days', 'Stage', 'Created Time', 'Closing Date', 'Offer Total Amount']].to_string(index=False))
# Out:
#                  Id  Create_to_Close_Days Stage        Created Time Closing Date  Offer Total Amount
# 5805028000006960031                   0.0  Lost 2023-09-07 10:05:00   2023-09-07                 NaN
# 5805028000004994120                   0.0  Lost 2023-08-17 20:32:00   2023-08-17                 NaN
# 5805028000005005105                   0.0  Lost 2023-08-17 20:23:00   2023-08-17                 NaN
# 5805028000004111309                   0.0  Lost 2023-08-08 16:23:00   2023-08-08                 NaN
# 5805028000001588071                   0.0  Lost 2023-07-13 10:01:00   2023-07-13                 NaN
# 5805028000004111157                   0.0  Lost 2023-08-08 14:40:00   2023-08-08              3500.0

# %%
# Analyze the reasons for the loss of deals by owners

# calculate the number of each cause of loss by owner
lost_reason_counts = lost_deals_df.groupby(['Deal Owner Name', 'Lost Reason']).size().reset_index(name='Count')

pivot_lost_reason = lost_reason_counts.pivot(index='Deal Owner Name', columns='Lost Reason', values='Count').fillna(0)

print(pivot_lost_reason)
# Out:
# Lost Reason      Changed Decision  Conditions are not suitable  \
# Deal Owner Name
# Alice Johnson                   0                           10
# Amy Green                       0                            0
# Ben Hall                      147                           34
# Bob Brown                       1                            8
# Cara Iverson                   82                           12
# Charlie Davis                 337                           54
# Diana Evans                   137                           29
# Eva Kent                       20                           12
# George King                     6                            6
# Ian Miller                     42                            4
# Jane Smith                     75                           29
# John Doe                        0                            0
# Julia Nelson                  227                          107
# Kevin Parker                   86                           16
# Mason Roberts                  50                            1
# Nina Scott                    113                           11
# Oliver Taylor                  34                            4
# Paula Underwood               138                           32
# Quincy Vincent                242                           71
# Rachel White                   34                           11
# Sam Young                       2                            0
# Ulysses Adams                 220                           39
# Victor Barnes                 122                           32
# Wendy Clark                     0                            0
# Xander Dean                     0                            0
# Yara Edwards                    4                            2
#
# Lost Reason      Considering a different direction in IT  \
# Deal Owner Name
# Alice Johnson                                          0
# Amy Green                                              0
# Ben Hall                                               7
# Bob Brown                                              0
# Cara Iverson                                           3
# Charlie Davis                                         11
# Diana Evans                                           25
# Eva Kent                                               2
# George King                                            4
# Ian Miller                                             0
# Jane Smith                                            11
# John Doe                                               0
# Julia Nelson                                           9
# Kevin Parker                                           4
# Mason Roberts                                          0
# Nina Scott                                             4
# Oliver Taylor                                          0
# Paula Underwood                                       21
# Quincy Vincent                                        15
# Rachel White                                           2
# Sam Young                                              0
# Ulysses Adams                                         28
# Victor Barnes                                          2
# Wendy Clark                                            0
# Xander Dean                                            0
# Yara Edwards                                           0
#
# Lost Reason      Didn't leave an application  \
# Deal Owner Name
# Alice Johnson                              0
# Amy Green                                  0
# Ben Hall                                  10
# Bob Brown                                  0
# Cara Iverson                               6
# Charlie Davis                             14
# Diana Evans                                8
# Eva Kent                                   2
# George King                                0
# Ian Miller                                 1
# Jane Smith                                 3
# John Doe                                   0
# Julia Nelson                              23
# Kevin Parker                               1
# Mason Roberts                              1
# Nina Scott                                 2
# Oliver Taylor                              0
# Paula Underwood                           10
# Quincy Vincent                            27
# Rachel White                               9
# Sam Young                                  1
# Ulysses Adams                             10
# Victor Barnes                              3
# Wendy Clark                                0
# Xander Dean                                0
# Yara Edwards                               0
#
# Lost Reason      Does not know how to use a computer  Does not speak English  \
# Deal Owner Name
# Alice Johnson                                      2                       0
# Amy Green                                          0                       1
# Ben Hall                                           3                      17
# Bob Brown                                          0                       5
# Cara Iverson                                       0                      12
# Charlie Davis                                      8                      12
# Diana Evans                                       13                      13
# Eva Kent                                           0                       2
# George King                                        1                       4
# Ian Miller                                         0                       3
# Jane Smith                                         1                       6
# John Doe                                           0                       0
# Julia Nelson                                       4                       8
# Kevin Parker                                       0                       3
# Mason Roberts                                      0                       2
# Nina Scott                                         1                       5
# Oliver Taylor                                      1                       0
# Paula Underwood                                    5                       9
# Quincy Vincent                                     2                      11
# Rachel White                                       1                       3
# Sam Young                                          0                       1
# Ulysses Adams                                      5                      15
# Victor Barnes                                      2                       5
# Wendy Clark                                        0                       0
# Xander Dean                                        0                       0
# Yara Edwards                                       0                       1
#
# Lost Reason      Doesn't Answer  Duplicate  Expensive  Gutstein refusal  ...  \
# Deal Owner Name                                                          ...
# Alice Johnson                 3          0          7                 0  ...
# Amy Green                     9         12          0                 0  ...
# Ben Hall                    230         38         38                11  ...
# Bob Brown                   200         96          0                 0  ...
# Cara Iverson                256         21         38                 5  ...
# Charlie Davis               481        128         54                35  ...
# Diana Evans                 312         70         50                 4  ...
# Eva Kent                     66          7          9                 0  ...
# George King                  28         10          2                 0  ...
# Ian Miller                  137         45          9                 1  ...
# Jane Smith                  259         77         42                12  ...
# John Doe                      0          6          0                 0  ...
# Julia Nelson                321        106         58                 7  ...
# Kevin Parker                142         56         14                 4  ...
# Mason Roberts               100         10         14                 0  ...
# Nina Scott                  194         58         38                 5  ...
# Oliver Taylor                 5          3          0                10  ...
# Paula Underwood             312         83         58                19  ...
# Quincy Vincent              351         72         72                 9  ...
# Rachel White                 81        527         15                 1  ...
# Sam Young                    17          9          1                 0  ...
# Ulysses Adams               326         76         67                37  ...
# Victor Barnes               224         42         28                 3  ...
# Wendy Clark                   1          1          0                 0  ...
# Xander Dean                   1          0          0                 0  ...
# Yara Edwards                 17         11          0                 0  ...
#
# Lost Reason      Invalid number  Next stream  Non target  Not for myself  \
# Deal Owner Name
# Alice Johnson                 0            0           0               0
# Amy Green                     3            0           1               0
# Ben Hall                     55            3         157               7
# Bob Brown                     9            0           0               2
# Cara Iverson                 36            1         203               4
# Charlie Davis               183           12         151              27
# Diana Evans                  55            1           0              13
# Eva Kent                     13            0          40               5
# George King                  12            0           1               2
# Ian Miller                  144            0          10               0
# Jane Smith                  135            0          12               7
# John Doe                      0            0           0               0
# Julia Nelson                167            6         138              11
# Kevin Parker                 62            3          12               2
# Mason Roberts                43            1           0               2
# Nina Scott                   93           27          90              11
# Oliver Taylor                 3            3           3               0
# Paula Underwood             130           20         235              18
# Quincy Vincent              105            7         185              11
# Rachel White                 42            1          68               1
# Sam Young                    13            0           4               0
# Ulysses Adams                88           41         180              18
# Victor Barnes                63            5         238               3
# Wendy Clark                   0            0           0               0
# Xander Dean                   2            0           0               0
# Yara Edwards                  4            0           8               0
#
# Lost Reason      Refugee  Stopped Answering  The contract did not fit  \
# Deal Owner Name
# Alice Johnson          0                  2                         0
# Amy Green              0                  0                         0
# Ben Hall               0                 94                         0
# Bob Brown              1                  2                         0
# Cara Iverson           0                 10                         1
# Charlie Davis          0                386                         0
# Diana Evans            0                 66                         1
# Eva Kent               0                 32                         0
# George King            0                  8                         0
# Ian Miller             0                 10                         2
# Jane Smith             0                105                         2
# John Doe               0                  0                         0
# Julia Nelson           0                208                         1
# Kevin Parker           0                 51                         3
# Mason Roberts          0                  2                         0
# Nina Scott             0                152                         3
# Oliver Taylor          0                 27                         0
# Paula Underwood        0                131                         5
# Quincy Vincent         0                124                         0
# Rachel White           0                  5                         0
# Sam Young              0                  0                         1
# Ulysses Adams          0                122                         2
# Victor Barnes          0                 19                         0
# Wendy Clark            0                  0                         0
# Xander Dean            0                  0                         0
# Yara Edwards           0                  0                         0
#
# Lost Reason      Thought for free  Went to Rivals  needs time to think
# Deal Owner Name
# Alice Johnson                   1               0                    0
# Amy Green                       1               0                    0
# Ben Hall                        7               1                   14
# Bob Brown                       2               1                    0
# Cara Iverson                    3               1                   11
# Charlie Davis                  38               6                   77
# Diana Evans                     5               4                   60
# Eva Kent                        0               1                    4
# George King                     0               0                    0
# Ian Miller                      0               2                   26
# Jane Smith                      7               3                   93
# John Doe                        0               0                    0
# Julia Nelson                    7               2                   39
# Kevin Parker                    3               1                   10
# Mason Roberts                   0               0                    3
# Nina Scott                      7               8                   32
# Oliver Taylor                   0               2                    3
# Paula Underwood                 8               2                   62
# Quincy Vincent                  5               6                   47
# Rachel White                    2               0                    5
# Sam Young                       1               0                    4
# Ulysses Adams                  12               6                   98
# Victor Barnes                   1               0                   17
# Wendy Clark                     0               0                    0
# Xander Dean                     0               0                    0
# Yara Edwards                    0               0                    1
#
# [26 rows x 21 columns]
# C:\Users\user\AppData\Local\Temp\ipykernel_12776\1759518263.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   lost_reason_counts = lost_deals_df.groupby(['Deal Owner Name', 'Lost Reason']).size().reset_index(name='Count')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# sort the owners and reasons for losses by total amount (for the entire table)
sorted_owners = pivot_lost_reason.sum(axis=1).sort_values(ascending=False).index
sorted_reasons = pivot_lost_reason.sum(axis=0).sort_values(ascending=False).index

pivot_sorted = pivot_lost_reason.loc[sorted_owners, sorted_reasons]

# take the top 10 owners
pivot_top10 = pivot_sorted.head(10)

# Normalize by rows for shares
pivot_norm = pivot_top10.div(pivot_top10.sum(axis=1), axis=0).fillna(0)
pivot_norm_percent = pivot_norm * 100

plt.figure(figsize=(14, 10))
sns.heatmap(
    pivot_norm_percent,
    annot=pivot_norm_percent.round(1),
    fmt='.1f',
    cmap='YlGnBu',
    cbar_kws={'label': 'Share of losses (%) from the total number of the owner'},
    linewidths=0.5,
    linecolor='gray',
)

plt.title('Heat map of reasons for lost deals by owner\n(numbers are the share of lost deals for each reason (%), colors are the share by owner)')
plt.xlabel('Lost Reason')
plt.ylabel('Deal Owner Name')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %%
# Analyze the quality of deals by owners

#count the number of deals of each quality by owners
quality_counts = deals_df.groupby(['Deal Owner Name', 'Quality'], observed=False).size().reset_index(name='Count')

# make a pivot table
pivot_quality = quality_counts.pivot(index='Deal Owner Name', columns='Quality', values='Count').fillna(0)

print(pivot_quality)
# Out:
# Quality          A - High  B - Medium  C - Low  D - Non Target  \
# Deal Owner Name
# Alice Johnson           0           0        0              25
# Amy Green               0           0        2               9
# Ben Hall               23         131      133             496
# Bob Brown               0           0        1              25
# Cara Iverson            5          24      142             408
# Charlie Davis          63         207      507             985
# Diana Evans            10          53      197             222
# Eva Kent                3          50       46             147
# George King             1           4       27              22
# Ian Miller             12          23       51              23
# Jane Smith             24          97      215             108
# John Doe                2           0        1               1
# Julia Nelson           50         166      479             511
# Kevin Parker           33          76       96              34
# Mason Roberts           3          30       56               8
# Nina Scott             20          96      203             403
# Oliver Taylor          20          73       57              10
# Paula Underwood        33         134      254             643
# Quincy Vincent         47         170      231             686
# Rachel White            2           4        4             131
# Sam Young               2           2       10              11
# Ulysses Adams          52         125      544             699
# Victor Barnes          22          87      178             603
# Wendy Clark             0           0        0               0
# Xander Dean             0           0        0               0
# Yara Edwards            0           0        0              18
# Zachary Foster          0           0        1               0
#
# Quality          E - Non Qualified  F - Unknown
# Deal Owner Name
# Alice Johnson                    0            0
# Amy Green                       19            0
# Ben Hall                       412            0
# Bob Brown                      299            2
# Cara Iverson                   360            0
# Charlie Davis                  806            0
# Diana Evans                    388            0
# Eva Kent                       117            0
# George King                     40            0
# Ian Miller                     348            0
# Jane Smith                     477            0
# John Doe                         4            0
# Julia Nelson                   711            0
# Kevin Parker                   288            0
# Mason Roberts                  137            0
# Nina Scott                     336            0
# Oliver Taylor                    1            0
# Paula Underwood                603            0
# Quincy Vincent                 592            0
# Rachel White                   709            0
# Sam Young                       32            0
# Ulysses Adams                  501            0
# Victor Barnes                  267            0
# Wendy Clark                      2            0
# Xander Dean                      3            0
# Yara Edwards                    33            0
# Zachary Foster                   0            0

# %%
# Make a heat map of deal quality

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.heatmap(pivot_quality, annot=True, fmt='.0f', cmap='YlGnBu', cbar_kws={'label': 'Number of deals'})

plt.title('Heat map of number of deals by quality and owners')
plt.xlabel('Quality')
plt.ylabel('Deal Owner Name')
plt.tight_layout()
plt.show()

# %%
# Create a summary table by campaigns, total number of deals, number of successful deals, conversion and sales amount
campaigns_effect = deals_df.groupby('Campaign', observed=False).agg(
    total_deals=('Id', 'count'),
    success_deals=('is_success', 'sum'),
    conversion_rate=('is_success', lambda x: round(x.sum() / x.count(), 2)),
    total_paid=('Offer Total Amount', 'sum')
).reset_index().sort_values(by='total_paid', ascending=False)
campaigns_effect
# Out:
#                               Campaign  total_deals  success_deals  \
# 113  performancemax_digitalmarkt_ru_de         2633            109
# 18                   12.07.2023wide_de         1569             48
# 150                  youtube_shorts_de         1624             53
# 2                      02.07.23wide_de          974             52
# 76                              dis_de          577             29
# ..                                 ...          ...            ...
# 141                           webanons            1              0
# 147                            work_wr            6              0
# 145                           women_de            1              0
# 144                            welt_de            2              0
# 151                youtube_shortsin_at           14              0
#
#      conversion_rate  total_paid
# 113             0.04   3333600.0
# 18              0.03   2064900.0
# 150             0.03   2018100.0
# 2               0.05   1661100.0
# 76              0.05   1228800.0
# ..               ...         ...
# 141             0.00         0.0
# 147             0.00         0.0
# 145             0.00         0.0
# 144             0.00         0.0
# 151             0.00         0.0
#
# [152 rows x 5 columns]

# %%
# Sort the campaigns by sales amount and take the largest 10 values
top10_campaigns_effect_paid = campaigns_effect.sort_values(by='total_paid', ascending=False).head(10)
top10_campaigns_effect_paid
# Out:
#                               Campaign  total_deals  success_deals  \
# 113  performancemax_digitalmarkt_ru_de         2633            109
# 18                   12.07.2023wide_de         1569             48
# 150                  youtube_shorts_de         1624             53
# 2                      02.07.23wide_de          974             52
# 76                              dis_de          577             29
# 19           12.09.23interests_uxui_de          529             26
# 4                        03.07.23women          612             29
# 5             04.07.23recentlymoved_de          749             30
# 8                       07.07.23lal_de          541             28
# 40              24.09.23retargeting_de          479             17
#
#      conversion_rate  total_paid
# 113             0.04   3333600.0
# 18              0.03   2064900.0
# 150             0.03   2018100.0
# 2               0.05   1661100.0
# 76              0.05   1228800.0
# 19              0.05   1221300.0
# 4               0.05   1162698.0
# 5               0.04   1139100.0
# 8               0.05   1056500.0
# 40              0.04    980400.0

# %%
# Sort the campaigns by conversion and take the largest 10 values
top10_campaigns_effect_conversion = campaigns_effect.sort_values(by='conversion_rate', ascending=False).head(10)
top10_campaigns_effect_conversion
# Out:
#               Campaign  total_deals  success_deals  conversion_rate  \
# 79              domain            1              1             1.00
# 91               hanna            1              1             1.00
# 123           referral            3              1             0.33
# 137         web2311_de           10              3             0.30
# 135         web1312_de           11              2             0.18
# 37        2005_lost_de            6              1             0.17
# 52       aussiedler_de            6              1             0.17
# 73              col_de            6              1             0.17
# 7    05.09.2023wide_de            6              1             0.17
# 15           1006start           19              3             0.16
#
#      total_paid
# 79       5000.0
# 91      11000.0
# 123      4000.0
# 137     16000.0
# 135     66500.0
# 37      33000.0
# 52      16000.0
# 73      20200.0
# 7       15000.0
# 15      37000.0

# %%
# Visualization of the efficiency of campaigns in terms of sales amounts and conversions
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
import seaborn as sns

# Setting up visualizations
sns.set(style="whitegrid")
fig, axes = plt.subplots(1, 2, figsize=(16, 6))  # 1 row, 2 columns
fig.suptitle("Assessing the effectiveness of campaigns", fontsize=18)

# Sales total by campaigns
sns.barplot(data=top10_campaigns_effect_paid, x='total_paid', y='Campaign',
            ax=axes[0])
axes[0].set_title("Total sales by campaigns")

# Format the X-axis: add thousand separators
axes[0].xaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{x:,.0f}'))

axes[0].set_xlabel("Sales amount")
axes[0].set_ylabel("Campaign")

# Conversion by campaigns
sns.barplot(data=top10_campaigns_effect_conversion, x='conversion_rate', y='Campaign',
            ax=axes[1])
axes[1].set_title("Conversion rate by campaigns")
axes[1].set_xlabel("Conversion")
axes[1].set_ylabel("")

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# visualize a combined graph on a graph with a double axis, where we will display advertising campaigns by sales amounts and their conversion

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FuncFormatter

fig, ax1 = plt.subplots(figsize=(14, 7))

top10_campaigns_effect_paid['Campaign'] = top10_campaigns_effect_paid['Campaign'].astype(str)

# Barplot for total_paid
sns.barplot(data=top10_campaigns_effect_paid, x='Campaign', y='total_paid', ax=ax1, color='skyblue')
ax1.set_ylabel('Total Paid', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Formatting numbers without abbreviations
ax1.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'.replace(',', ' ')))  # for example, 1 000 000

# Explicitly set positions and labels for xticks
ax1.set_xticks(range(len(top10_campaigns_effect_paid)))
ax1.set_xticklabels(top10_campaigns_effect_paid['Campaign'], rotation=45, ha='right')

# Second y-axis for conversion 
ax2 = ax1.twinx()
sns.lineplot(data=top10_campaigns_effect_paid, x='Campaign', y='conversion_rate', ax=ax2, color='red', marker='o')
ax2.set_ylabel('Conversion Rate', color='red')
ax2.tick_params(axis='y', labelcolor='red')

plt.title('Total Paid and Conversion Rate by Top 10 Campaigns')
plt.tight_layout()
plt.show()

# %%
# analyze the sales of the Top 10 advertising campaigns with high conversion, for this we will build a combined graph with a double axis

import matplotlib.pyplot as plt
import seaborn as sns
fig, ax1 = plt.subplots(figsize=(14, 7))

top10_campaigns_effect_conversion['Campaign'] = top10_campaigns_effect_conversion['Campaign'].astype(str)

# Barplot for total_paid
sns.barplot(data=top10_campaigns_effect_conversion, x='Campaign', y='total_paid', ax=ax1, color='skyblue')
ax1.set_ylabel('Total Paid', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Explicitly set positions and labels for xticks
ax1.set_xticks(range(len(top10_campaigns_effect_conversion)))
ax1.set_xticklabels(top10_campaigns_effect_conversion['Campaign'], rotation=45, ha='right')

# Second y-axis for conversion
ax2 = ax1.twinx()
sns.lineplot(data=top10_campaigns_effect_conversion, x='Campaign', y='conversion_rate', ax=ax2, color='red', marker='o')
ax2.set_ylabel('Conversion Rate', color='red')
ax2.tick_params(axis='y', labelcolor='red')

plt.title('Total Paid and Conversion Rate by Top 10 Campaigns')
plt.tight_layout()
plt.show()

# %%
import plotly.express as px
import plotly.graph_objects as go

# Filter deals with non-empty SLA_range
deals_with_sla = deals_df[deals_df['SLA_range'].notna()]

# Separate successful and unsuccessful deals
successful = deals_with_sla[(deals_with_sla['Stage'] == 'Payment Done') & (deals_with_sla['Offer Total Amount'].notna())]
unsuccessful = deals_with_sla[(deals_with_sla['Stage'] != 'Payment Done') & (deals_with_sla['Offer Total Amount'].isna())]

# Group by SLA_range
success_counts = successful['SLA_range'].value_counts().sort_index()
unsuccess_counts = unsuccessful['SLA_range'].value_counts().sort_index()

# Align categories order
sla_categories = [
    'Very fast (≤5 min)',
    'Fast (5-15 min)',
    'Medium (15-30 min)',
    'Slow (30-60 min)',
    'Very slow (>60 min)'
]

success_counts = success_counts.reindex(sla_categories, fill_value=0)
unsuccess_counts = unsuccess_counts.reindex(sla_categories, fill_value=0)

total_counts = success_counts + unsuccess_counts
conversion_rate = (success_counts / total_counts * 100).fillna(0)

fig = go.Figure()

fig.add_trace(go.Bar(
    x=sla_categories,
    y=total_counts,
    name='Total Deals',
    marker_color='skyblue',
    text=total_counts,
    textposition='inside',  # labels inside bars
    textfont=dict(size=14, color='white')
))

fig.add_trace(go.Scatter(
    x=sla_categories,
    y=conversion_rate,
    name='Successful Deals Conversion Rate (%)',
    mode='lines+markers+text',
    marker=dict(color='rgba(178,34,34,0.4)', size=10),  # semi-transparent color
    line=dict(color='rgba(178,34,34,0.4)', width=2, dash='dash'),  # semi-transparent dashed line
    text=[f"{v:.1f}%" for v in conversion_rate],
    textposition='top right',
    textfont=dict(size=12, color='firebrick'),
    yaxis='y2'
))

fig.update_layout(
    title='Dependence of Successful Deals Conversion on SLA',
    xaxis=dict(title='SLA Category', tickangle=-45),
    yaxis=dict(
        title='Number of Deals',
        showgrid=True,
        gridcolor='lightgrey',
        zeroline=False,
    ),
    yaxis2=dict(
        title='Conversion Rate of Successful Deals (%)',
        overlaying='y',
        side='right',
        showgrid=False,
        zeroline=False,
        range=[0, 100]
    ),
    barmode='group',
    plot_bgcolor='white',
    paper_bgcolor='white',
    height=700,
    font=dict(size=14),
    legend=dict(
        orientation='h',
        yanchor='bottom',
        y=1.02,
        xanchor='right',
        x=1
    )
)

fig.show()
