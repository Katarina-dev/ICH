# %%
import pandas as pd

df = pd.read_pickle("deals_cleaned_v1.pkl")

# %%
df
# Out:
#                         Id Deal Owner Name Closing Date            Quality  \
# 0      5805028000056864695        Ben Hall          NaT         B - Medium
# 1      5805028000056859489   Ulysses Adams          NaT         B - Medium
# 2      5805028000056832357   Ulysses Adams   2024-06-21     D - Non Target
# 3      5805028000056824246        Eva Kent   2024-06-21  E - Non Qualified
# 4      5805028000056873292        Ben Hall   2024-06-21     D - Non Target
# ...                    ...             ...          ...                ...
# 21588  5805028000000970006      Jane Smith   2023-07-04  E - Non Qualified
# 21589  5805028000000948010      Jane Smith   2023-08-29         B - Medium
# 21590  5805028000000945016      Jane Smith   2023-08-29           A - High
# 21591  5805028000000927004       Bob Brown   2023-07-09     D - Non Target
# 21592  5805028000000922001       Bob Brown   2023-07-03  E - Non Qualified
#
#           Stage             Lost Reason                   Page  \
# ...

# %%
df[df['Quality'] == 'F']
# Out:
#                         Id Deal Owner Name Closing Date Quality Stage  \
# 20698  5805028000004112371       Bob Brown   2023-08-08       F  Lost
# 20699  5805028000004130362       Bob Brown   2023-08-08       F  Lost
# 20716  5805028000004121236       Bob Brown   2023-08-08       F  Lost
#
#       Lost Reason   Page Campaign SLA Content  ...        Created Time  \
# 20698   Duplicate  /test      NaN NaT     NaN  ... 2023-08-08 20:52:00
# 20699   Duplicate  /test      NaN NaT     NaN  ... 2023-08-08 20:48:00
# 20716   Duplicate  /test      NaN NaT     NaN  ... 2023-08-08 15:12:00
#
#       Course duration Months of study Initial Amount Paid Offer Total Amount  \
# 20698             NaN            <NA>                 0.0                0.0
# 20699             NaN            <NA>               500.0             3000.0
# 20716             NaN            <NA>                 NaN                0.0
#
#               Contact Name City  Level of Deutsch  Created Date  Date Diff
# ...
